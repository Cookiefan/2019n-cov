# %%
#coding:utf-8
import pandas as pd
import numpy as np
import scipy.integrate as spi
import matplotlib.pyplot as plt
from ncov.reader import get_data,watch_data
## test:
# get_data('湖北', '武汉', '2020-01-01', '2020-02-08')

# %%
import torch
from torch.nn.parameter import Parameter
torch.set_default_tensor_type(torch.DoubleTensor)

# %%
class SEIR_cell(torch.nn.Module):
    def __init__(self, N, beta_init, gamma_2_init, theta_init):
        super(SEIR_cell, self).__init__()
        # self.date_len = date_len
        self.beta = Parameter(torch.tensor([beta_init], requires_grad=True))
        self.N = Parameter(torch.tensor([N], requires_grad=True))
        self.gamma_1 = torch.tensor([0.])
        self.gamma_2 = Parameter(torch.tensor([gamma_2_init], requires_grad=True))
        self.alpha = torch.tensor([1.])
        self.theta = Parameter(torch.tensor([theta_init], requires_grad=True))
        self.omega = torch.tensor([0.])
        # self.E_ratio = Parameter(torch.tensor([3.], requires_grad=True))


    def clamp(self, X):
        # return torch.clamp(X, min=0, max=self.N)
        return X

    def act(self, X):
        # return torch.nn.LeakyReLU(0.1)(X)
        # return torch.relu(X)
        return torch.pow(X, 2)

    def forward(self, X):
        S, confirm, Exposed, recover, dead = X
        # self.beta = beta_old + self.beta_add
        # self.gamma_2 = gamma_2_old + self.gamma_2_add
        S_rest = S + self.act(self.omega)*Exposed - self.act(self.beta)*confirm*S/self.N # dS/dt
        E = Exposed + self.act(self.beta)*confirm*S/self.N - (self.act(self.alpha)+self.act(self.omega))*Exposed # dE/dt

        I = confirm + self.act(self.alpha)*Exposed - (self.act(self.gamma_2)+ self.act(self.theta))*confirm # dI/dt
        R = recover + self.act(self.gamma_2)*confirm # dR/dt
        D = dead + self.act(self.theta)*confirm

        # I = confirm + self.act(self.alpha)*E - self.act(self.gamma_2)*confirm - self.act(self.theta)*confirm # dI/dt
        # R = recover + self.act(self.gamma_2)*I # dR/dt
        # D = dead + self.act(self.theta)*I

        return S_rest, I, E, R, D, self.beta, self.gamma_2, self.theta, self.N

# %%
class SEIR_model(torch.nn.Module):
    def __init__(self, date_len, pred_date_len=0, N=2870000., beta_init=0.2586,  gamma_2_init=0.018, theta_init=0.001, E_ratio_init=3., I_init=41, R_init=2., D_init=0.):
        super(SEIR_model, self).__init__()
        self.date_len = date_len
        self.SEIR_cells = torch.nn.ModuleList()
        self.SEIR_pred_cells = torch.nn.ModuleList()
        self.N = N
        self.E_ratio = E_ratio_init
        # self.I = (1e-6)*self.N
        # self.E = (self.I * self.E_ratio)
        # self.R = (1e-6 / 2)*self.N
        # self.S = (self.N - self.I - self.E - self.R)
        # self.beta = Parameter(torch.tensor([beta_init], requires_grad=True))
        # self.gamma_2 = Parameter(torch.tensor([gamma_2_init], requires_grad=True))
        self.beta = beta_init
        self.gamma_2 = gamma_2_init
        self.theta = theta_init
        self.I = I_init
        self.E = (self.I * self.E_ratio)
        self.R = R_init
        self.D = D_init
        self.S = (self.N - self.I - self.E - self.R - self.D)
        self.date_len = date_len-1
        self.pred_date_len = pred_date_len
        # self.date_total_len = self.date_len + self.pred_date_len
        for i in range(self.date_len):
            self.SEIR_cells.append(SEIR_cell(self.N,self.beta,self.gamma_2, self.theta))

        self.S_tensor_cur = torch.zeros((self.date_len+1,))
        self.I_tensor_cur = torch.zeros((self.date_len+1,))
        self.E_tensor_cur = torch.zeros((self.date_len+1,))
        self.R_tensor_cur = torch.zeros((self.date_len+1,))
        self.D_tensor_cur = torch.zeros((self.date_len+1,))
        
    
    def forward(self, X):
        inp = self.S, self.I, self.E, self.R, self.D
        # param = beta_init, gamma_2_init
        S_tensor = torch.zeros((self.date_len+1,))
        I_tensor = torch.zeros((self.date_len+1,))
        E_tensor = torch.zeros((self.date_len+1,))
        R_tensor = torch.zeros((self.date_len+1,))
        D_tensor = torch.zeros((self.date_len+1,))
        S_tensor[0], I_tensor[0], E_tensor[0], R_tensor[0], D_tensor[0] = inp
        for i in range(self.date_len):
            S, I, E, R, D, beta_cur, gamma_2_cur, theta_cur, N = self.SEIR_cells[i](inp)
            S_tensor[i+1], I_tensor[i+1], E_tensor[i+1], R_tensor[i+1], D_tensor[i+1] = S, I, E, R, D
            self.beta = beta_cur
            self.gamma_2 = gamma_2_cur
            self.theta = theta_cur
            self.S_cur = S
            self.I_cur = I
            self.E_cur = E
            self.R_cur = R
            self.D_cur = D
            self.N_cur = N
            inp = [S, I, E, R, D]
        self.S_tensor_cur, self.I_tensor_cur, self.E_tensor_cur, self.R_tensor_cur, self.D_tensor_cur = S_tensor, I_tensor, E_tensor, R_tensor, D_tensor
        return S_tensor, I_tensor, E_tensor, R_tensor, D_tensor, beta_cur, gamma_2_cur

    def pred(self, pred_date_len, N_cur=0, beta=0, gamma_2=0, theta=0):
        if N_cur==0:
            N_cur=self.N_cur
            beta=self.beta
            gamma_2=self.gamma_2
            theta=self.theta

        cur_pred_cells_len = len(self.SEIR_pred_cells)
        # print("cur_pred_cells_len:", cur_pred_cells_len)
        if cur_pred_cells_len!=pred_date_len:
            self.SEIR_pred_cells = torch.nn.ModuleList()
            for i in range(pred_date_len):
                self.SEIR_pred_cells.append(SEIR_cell(N_cur,beta,gamma_2,theta))
        S_pred_tensor = torch.zeros((pred_date_len,))
        I_pred_tensor = torch.zeros((pred_date_len,))
        E_pred_tensor = torch.zeros((pred_date_len,))
        R_pred_tensor = torch.zeros((pred_date_len,))
        D_pred_tensor = torch.zeros((pred_date_len,))
        # pred:
        inp = self.S_cur, self.I_cur, self.E_cur, self.R_cur, self.D_cur
        for i in range(pred_date_len):
            S, I, E, R, D, beta_, gamma_2_, theta_, N_ = self.SEIR_pred_cells[i](inp)
            S_pred_tensor[i], I_pred_tensor[i], E_pred_tensor[i], R_pred_tensor[i], D_pred_tensor[i] = S, I, E, R, D
            inp = [S, I, E, R, D]
        return S_pred_tensor, I_pred_tensor, E_pred_tensor, R_pred_tensor, D_pred_tensor

# %%
def plot_daily_acc(data, accumulated_confirmed, accumulated_pred_confirmed, xlen=10, city='武汉', pred_date_len=0):
    # len_data = len(list(set(data.index)))
    # print(len_data)
    T_name = 'time'
    plt.figure(figsize=(xlen, 6))
    # accumulated_confirmed = data[I_name]
    # accumulated_death = data['accumulated_death']
    # accumulated_recovered = data[R_name]
    time_val = data[T_name].values
    
    max_time_val = data[T_name].values.max()
    pred_time = []
    for i in range(1,pred_date_len+1):
        pred_time.append(max_time_val+np.timedelta64(i,'D')) 
    # print(pred_time)
    if pred_time==[]:
        merge_time = time_val
    else:
        merge_time = np.concatenate((time_val, pred_time),axis=0)
    plt.plot(time_val, accumulated_confirmed, color = 'red', label = '累计确诊人数',marker = 'x')
    plt.plot(merge_time, accumulated_pred_confirmed, color = 'blue',label = '预测的累计确诊人数',marker = 'x')
    # plt.plot(accumulated_death, color = 'gray',label = '累计死亡人数',marker = 'x')
    # plt.plot(time_val, accumulated_recovered, color = 'green', label = '累计治愈人数',marker = '.')
    # plt.plot(merge_time, pred_R, color = 'black', label = '预测的累计治愈人数',marker = '.')
    # plt.plot(RES[:,2],color = 'orange',label = 'The Exposed',marker = '.')
    # plt.plot(RES[:,3],color = 'green',label = 'The Recovered',marker = '.')
    # for a, b in zip(merge_time, pred_I):
    #     plt.text(a, b+0.3, b, ha='center', va='bottom', fontsize=12, color='blue')
    # for a, b in zip(time_val, accumulated_confirmed):
    #     plt.text(a, b-10, b, ha='center', va='bottom', fontsize=12, color='red')
    for a,b in zip(merge_time, accumulated_pred_confirmed):
        plt.annotate('%s'%(b),xy=(a,b),xytext=(-5,5), textcoords='offset points',color='blue')
    for a,b in zip(time_val, accumulated_confirmed):
        plt.annotate('%s'%(b),xy=(a,b),xytext=(-5,20), textcoords='offset points',color='red')

    city_title = '疫情状况-'+city
    plt.title(city_title)
    plt.legend()
    plt.xlabel('日期')   
    plt.ylabel('人数')
    plt.show()

# %%
def plot_daily_new(data, new_confirm, pred_new_confirm, xlen=10, city='武汉', pred_date_len=0):
    # len_data = len(list(set(data.index)))
    # print(len_data)
    plt.figure(figsize=(xlen, 6))
    T_name = 'time'
    time_val = data[T_name].values
    time_val = time_val[1:]
    max_time_val = data[T_name].values.max()
    pred_time = []
    for i in range(1,pred_date_len+1):
        pred_time.append(max_time_val+np.timedelta64(i,'D')) 
    # print(pred_time)
    if pred_time==[]:
        merge_time = time_val
    else:
        merge_time = np.concatenate((time_val, pred_time),axis=0)
    plt.plot(time_val, new_confirm, color = 'red', label = '新增确诊人数',marker = 'x')
    plt.plot(merge_time, pred_new_confirm, color = 'blue',label = '新增累计确诊人数',marker = 'x')
    # plt.plot(accumulated_death, color = 'gray',label = '累计死亡人数',marker = 'x')
    # plt.plot(time_val, accumulated_recovered, color = 'green', label = '累计治愈人数',marker = '.')
    # plt.plot(merge_time, pred_R, color = 'black', label = '预测的累计治愈人数',marker = '.')
    # plt.plot(RES[:,2],color = 'orange',label = 'The Exposed',marker = '.')
    # plt.plot(RES[:,3],color = 'green',label = 'The Recovered',marker = '.')
    # for a, b in zip(merge_time, pred_I):
    #     plt.text(a, b+0.3, b, ha='center', va='bottom', fontsize=12, color='blue')
    # for a, b in zip(time_val, accumulated_confirmed):
    #     plt.text(a, b-10, b, ha='center', va='bottom', fontsize=12, color='red')
    for a,b in zip(merge_time, pred_new_confirm):
        plt.annotate('%s'%(b),xy=(a,b),xytext=(-5,5), textcoords='offset points',color='blue')
    for a,b in zip(time_val, new_confirm):
        plt.annotate('%s'%(b),xy=(a,b),xytext=(-5,20), textcoords='offset points',color='red')

    city_title = '疫情状况-'+city
    plt.title(city_title)
    plt.legend()
    plt.xlabel('日期')   
    plt.ylabel('人数')
    plt.show()

# %%
import torch.optim as optim
import os
# def loss_fn(pred, gt):
#     T = gt.shape
#     loss = torch.tensor([0.])
#     for i in range(T.data.numpy()):
#         loss = loss + torch.mean((i+1)*torch.pow(pred[i]-gt[i],2))
    # return loss
def make_dir(city, date):
    save_root_path = 'models/'
    model_city_path = os.path.join(save_root_path,city)
    
    model_city_date_path = os.path.join(model_city_path,date)

    if not os.path.exists(model_city_date_path):
        print(model_city_date_path)
        os.makedirs(model_city_date_path)
    return model_city_date_path

def lr_decay(global_step,learning_rate=0.01,decay_rate=0.8,decay_steps=300):
    decayed_learning_rate = learning_rate * np.power(decay_rate,(global_step / decay_steps))
    return decayed_learning_rate

def train(data, model_city_date_path, N=1e7, I_init=1e-6, R_init=1e-6/2., D_init=1e-6/6., features=['accumulated_confirmed', 'accumulated_recovered', 'accumulated_death'], max_epoches = 400):
    model_pt = os.path.join(model_city_date_path,'model.pt')
    data_feat = data[features]
    Input = np.array(data_feat,dtype=np.float)
    print(Input.shape)
    date_len = len(Input)
    print(date_len)
    model = SEIR_model(date_len,  pred_date_len = 10, N=N, I_init=I_init, R_init=R_init, D_init=D_init)
    # Learning rate for optimizers
    lr = 0.01
    lr_init = lr
    # Beta1 hyperparam for Adam optimizers
    beta1 = 0.5
    # I_pred_list = []
    # R_pred_list = []
    optimizer = optim.Adam(model.parameters(), lr=lr, betas=(beta1, 0.999))
    loss_min = 1e8
    for step in range(max_epoches):
        print("Training step: ", step)
        Input = torch.tensor(Input)
        model_inp = Input[:-1]
        S,I,E,R,D, beta,gamma_2 = model(model_inp.float())
        # print(output)
        loss_fn = torch.nn.MSELoss()
        pred_I = I
        pred_recovered = R
        pred_dead = D
        pred_confirm = pred_I+pred_recovered+pred_dead
        # print(pred_confirmed)
        
        I_gt_tensor = Input[:,0]
        recovered_gt_tensor = Input[:,1]
        dead_gt_tensor = Input[:,2]
        confirm_gt = I_gt_tensor+recovered_gt_tensor+dead_gt_tensor
        # print(recovered_gt_tensor)
        # print(pred_confirmed.shape)
        # loss = loss_fn(pred_confirmed,confirmed_gt_tensor)
        loss = 0.1*(loss_fn(pred_confirm, confirm_gt) + loss_fn(pred_I, I_gt_tensor) + 4*loss_fn(pred_recovered, recovered_gt_tensor) + 4*loss_fn(pred_dead, dead_gt_tensor))
        # loss = loss_fn(pred_confirmed, confirmed_gt_tensor) + loss_fn(pred_recovered, recovered_gt_tensor) + loss_fn(pred_dead, dead_gt_tensor)
        print("Loss: {}".format(loss))
        if loss<loss_min:
            loss_min = loss
            torch.save(model, model_pt)
        learning_rate = lr_decay(step,lr_init,decay_steps=300)
        optimizer = optim.Adam(model.parameters(), lr=learning_rate, betas=(beta1, 0.999))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print("Loss_min:",loss_min)
    return S,I,E,R,D


# model_city_date_path = make_dir('wuhan','02-03')
# features=['accumulated_confirmed', 'accumulated_recovered']
# S,I,E,R,model = train(data_wh_feat, model_city_date_path, N=2870000., I_init=41, R_init=2., features=features, max_epoches=400)

# %%
def load_model_predict(model_city_date_path, data, N_cur=0,beta=0,gamma_2=0,theta=0, city_name='深圳',c='confirmed', features=['I','cured','dead'], pred_date_len=5):
    I_name,recover_name,dead_name = features
    model_pt = os.path.join(model_city_date_path,'model.pt')
    model = torch.load(model_pt)
    I = model.I_tensor_cur
    R = model.R_tensor_cur
    D = model.D_tensor_cur
    I_pred_old = (I.detach().numpy()).astype(np.int)
    R_pred_old = (R.detach().numpy()).astype(np.int)
    D_pred_old = (D.detach().numpy()).astype(np.int)

    confirm_pred = cal_acc_confirm(I_pred_old,R_pred_old,D_pred_old)
    confirm_origin = get_data_acc_confirm(data,c=c)
    print(confirm_origin)
    plot_daily_acc(data, confirm_origin, confirm_pred, city=city_name)


    new_confirm = cal_new_confirm(np.array(data[I_name]),np.array(data[recover_name]),np.array(data[dead_name]))
    cal_acc_confirm(I_pred_old,R_pred_old,D_pred_old)
    new_confirm_pred = cal_new_confirm(I_pred_old,R_pred_old,D_pred_old)

    S_pred_tensor, I_pred_tensor, E_pred_tensor, R_pred_tensor, D_pred_tensor = model.pred(N_cur=N_cur,beta=beta,gamma_2=gamma_2,theta=theta, pred_date_len = pred_date_len)
    I_pred_new = (I_pred_tensor.detach().numpy()).astype(np.int)
    R_pred_new = (R_pred_tensor.detach().numpy()).astype(np.int)
    D_pred_new = (D_pred_tensor.detach().numpy()).astype(np.int)
    I_pred_total = np.concatenate((I_pred_old,I_pred_new),axis=0)
    R_pred_total = np.concatenate((R_pred_old,R_pred_new),axis=0)
    D_pred_total = np.concatenate((D_pred_old,D_pred_new),axis=0)

    confirm_pred = cal_acc_confirm(I_pred_total,R_pred_total,D_pred_total)
    print('confirm_pred',confirm_pred)
    confirm_origin = get_data_acc_confirm(data,c=c)
    plot_daily_acc(data, confirm_origin, confirm_pred, city=city_name, pred_date_len=pred_date_len)

    new_confirm_pred_total = cal_new_confirm(I_pred_total,R_pred_total,D_pred_total)
    new_confirm_pred_total

    plot_daily_new(data, new_confirm, new_confirm_pred_total, city=city_name, pred_date_len=pred_date_len)

# %%
# # data_china = pd.read_excel('./ncov/data/nation_data.xlsx')
# data_china = pd.read_csv('./ncov/data/nation/nation.csv')
# data_china

# %%
# data_china['time'] = data_china['time'].apply(lambda x: '2020/'+x.replace('月','/').replace('日',''))
# data_china['time'] = pd.to_datetime(data_china['time'])

# %%
# data_china['accumulated_confirmed']

# %%
# model_city_date_path = make_dir('china','02-08')
# features=['accumulated_confirmed', 'accumulated_cured', 'accumulated_death']
# I_init = float(data_china['accumulated_confirmed'].iloc[0])
# R_init = float(data_china['accumulated_cured'].iloc[0])
# D_init = float(data_china['accumulated_death'].iloc[0])
# N = 13000000000.
# S_china,I_china,E_china,R_china,D_china = train(data_china, model_city_date_path, N=N, I_init=I_init, R_init=R_init, D_init=D_init, features=features, max_epoches=2000)

# %%
# model_city_date_path='models/china/02-08'

# %%
# param = {'beta_model_3': 0.09111736783585582, 'gamma_2_model_3': 0.016532860820465893, 'N_model_3': 13000000000.106674, 'theta_model_3': 0.006605514213817316}
# def change_key(param,i):
#     for k in list(param.keys()):
#         old_key = k
#         new_key = k.replace(f'_model_{i}','')
#         param[new_key]=param.pop(old_key)
#     return param
# param = change_key(param,3)
# param

# %%
# load_model_predict(model_city_date_path, data_china, N_cur=param['N'],beta=param['beta'],gamma_2=param['gamma_2'],theta=param['theta'],city_name='全国', c='accumulated_confirmed', features=features)

# %%
# merge_data = pd.read_csv('./ncov/data/nation/allcity_20200209.csv')
# merge_data = merge_data.rename(columns = {'updatetime':'time'})
# merge_data['time'] = merge_data['time'].apply(lambda x: '2020/'+x)
# merge_data['time']

# %%
# merge_data['I'] = merge_data['confirmed']-merge_data['dead']-merge_data['cured']
# merge_data['I']

# %%
# merge_data['time']= pd.to_datetime(merge_data['time'])
# merge_data['time']

# %%
def read_data(path):
    data = pd.read_csv(path)
    data['I'] = data['confirmed']-data['dead']-data['cured']
    # data['E']=data['suspected']+data['close_contact']+data['under_medical_observation']
    data['time']= pd.to_datetime(data['time'])
    # data['time'] = data['time'].apply(lambda x:x-np.timedelta64(1,'D'))
    return data

# %%
data_sz = read_data('./ncov/data/shenzhen_截至0210_24时.csv')
# data_sz['I'] = data_sz['confirmed']-data_sz['dead']-data_sz['cured']
# data_sz['time']= pd.to_datetime(data_sz['time'])
data_sz
# Out:
#     confirmed  suspected  dead  cured  close_contact       time    I
# 0          36          0     0      2              0 2020-01-26   34
# 1          49          0     0      3              0 2020-01-27   46
# 2          63          0     0      4              0 2020-01-28   59
# 3          86          0     0      4            291 2020-01-29   82
# 4         110          0     0      4            325 2020-01-30  106
# 5         170          0     0      4            327 2020-01-31  166
# 6         196          0     0      5            569 2020-02-01  191
# 7         226          0     0      5            662 2020-02-02  221
# 8         269          0     0     10            904 2020-02-03  259
# 9         289          0     0     13            878 2020-02-04  276
# 10        314          0     0     16            947 2020-02-05  298
# 11        334          0     0     22            958 2020-02-06  312
# 12        351          0     0     31           1045 2020-02-07  320
# 13        364          0     0     31           1153 2020-02-08  333
# 14        368          0     0     46           1104 2020-02-09  322
# 15        375          0     0     56            950 2020-02-10  319

# %%
def cal_acc_confirm(I,R,D):
    return I+R+D
def cal_new_confirm(I,R,D):
    acc_confirm = cal_acc_confirm(I,R,D)
    new_confirm = np.zeros((len(acc_confirm)-1))
    for i in range(len(acc_confirm)-1):
        new_confirm[i] = acc_confirm[i+1]-acc_confirm[i]
    return new_confirm
def get_data_acc_confirm(data,c='confirmed'):
    return np.array(data[c])

# %%
model_city_date_path = make_dir('shenzhen','02-10')
features=['I', 'cured','dead']
I_init = float(data_sz['I'].iloc[0])
R_init = float(data_sz['cured'].iloc[0])
D_init = float(data_sz['dead'].iloc[0])
N = 13026600.
S,I,E,R,D = train(data_sz, model_city_date_path, N=N, I_init=I_init, R_init=R_init, D_init=D_init, features=features, max_epoches=6000)
# Out:
# 563
# Loss: 196.7511850363963
# Training step:  5564
# Loss: 196.75319288170977
# Training step:  5565
# Loss: 196.75118141962932
# Training step:  5566
# Loss: 196.75318631365616
# Training step:  5567
# Loss: 196.7511777822738
# Training step:  5568
# Loss: 196.75317976502026
# Training step:  5569
# Loss: 196.75117416375303
# Training step:  5570
# Loss: 196.75317323148988
# Training step:  5571
# Loss: 196.75117059249385
# Training step:  5572
# Loss: 196.75316671707887
# Training step:  5573
# Loss: 196.75116329869047
# Training step:  5574
# Loss: 196.75316088953758
# Training step:  5575
# Loss: 196.751159718651
# Training step:  5576
# Loss: 196.75315440592288
# Training step:  5577
# Loss: 196.7511561866153
# Training step:  5578
# Loss: 196.75314793749894
# Training step:  5579
# Loss: 196.75115265024908
# Training step:  5580
# Loss: 196.75314148778898
# Training step:  5581
# Loss: 196.75114914036772
# Training step:  5582
# Loss: 196.75313505331033
# Training step:  5583
# Loss: 196.75114564163394
# Training step:  5584
# Loss: 196.75312863731858
# Training step:  5585
# Loss: 196.75114209972833
# Training step:  5586
# Loss: 196.75312223665227
# Training step:  5587
# Loss: 196.75113858720567
# Training step:  5588
# Loss: 196.75311585423185
# Training step:  5589
# Loss: 196.75113512531192
# Training step:  5590
# Loss: 196.75310948699658
# Training step:  5591
# Loss: 196.7511316521791
# Training step:  5592
# Loss: 196.75310313792062
# Training step:  5593
# Loss: 196.7511282149089
# Training step:  5594
# Loss: 196.7530968040294
# Training step:  5595
# Loss: 196.751124804481
# Training step:  5596
# Loss: 196.75309048805227
# Training step:  5597
# Loss: 196.75112050680605
# Training step:  5598
# Loss: 196.75308422265357
# Training step:  5599
# Loss: 196.75111711572887
# Training step:  5600
# Loss: 196.75307793896155
# Training step:  5601
# Loss: 196.75111369055753
# Training step:  5602
# Loss: 196.7530716705346
# Training step:  5603
# Loss: 196.75111032659981
# Training step:  5604
# Loss: 196.75306541959398
# Training step:  5605
# Loss: 196.75110696360184
# Training step:  5606
# Loss: 196.75305918385854
# Training step:  5607
# Loss: 196.7511036137382
# Training step:  5608
# Loss: 196.75305296547873
# Training step:  5609
# Loss: 196.7511002700576
# Training step:  5610
# Loss: 196.75304676225022
# Training step:  5611
# Loss: 196.7510969080574
# Training step:  5612
# Loss: 196.75304057621662
# Training step:  5613
# Loss: 196.75109357284884
# Training step:  5614
# Loss: 196.75303440518493
# Training step:  5615
# Loss: 196.75109028552748
# Training step:  5616
# Loss: 196.75302825096747
# Training step:  5617
# Loss: 196.75108699862983
# Training step:  5618
# Loss: 196.7530221115644
# Training step:  5619
# Loss: 196.75108373487978
# Training step:  5620
# Loss: 196.75301598815676
# Training step:  5621
# Loss: 196.75108046302387
# Training step:  5622
# Loss: 196.75300987236824
# Training step:  5623
# Loss: 196.75107718266565
# Training step:  5624
# Loss: 196.75066248566245
# Training step:  5625
# Loss: 196.74943461082736
# Training step:  5626
# Loss: 196.75058923895918
# Training step:  5627
# Loss: 196.74943081852746
# Training step:  5628
# Loss: 196.750583752019
# Training step:  5629
# Loss: 196.74942699721865
# Training step:  5630
# Loss: 196.75057827875048
# Training step:  5631
# Loss: 196.749423223232
# Training step:  5632
# Loss: 196.75057281900501
# Training step:  5633
# Loss: 196.74941945666373
# Training step:  5634
# Loss: 196.7505673622196
# Training step:  5635
# Loss: 196.74941570542796
# Training step:  5636
# Loss: 196.750561934366
# Training step:  5637
# Loss: 196.74941194381307
# Training step:  5638
# Loss: 196.75055651895224
# Training step:  5639
# Loss: 196.74940821837677
# Training step:  5640
# Loss: 196.7505511081714
# Training step:  5641
# Loss: 196.74940450078554
# Training step:  5642
# Loss: 196.75054572399046
# Training step:  5643
# Loss: 196.7494005705463
# Training step:  5644
# Loss: 196.75054035465214
# Training step:  5645
# Loss: 196.74939518138092
# Training step:  5646
# Loss: 196.75053511935113
# Training step:  5647
# Loss: 196.74939151582194
# Training step:  5648
# Loss: 196.7505297780554
# Training step:  5649
# Loss: 196.7493878436368
# Training step:  5650
# Loss: 196.75052444893893
# Training step:  5651
# Loss: 196.7493842047787
# Training step:  5652
# Loss: 196.75051912420773
# Training step:  5653
# Loss: 196.74938056076815
# Training step:  5654
# Loss: 196.75051382613395
# Training step:  5655
# Loss: 196.74937694241495
# Training step:  5656
# Loss: 196.75050854070705
# Training step:  5657
# Loss: 196.74937332428829
# Training step:  5658
# Loss: 196.75050325920924
# Training step:  5659
# Loss: 196.7493697293451
# Training step:  5660
# Loss: 196.75049800444427
# Training step:  5661
# Loss: 196.7493661300194
# Training step:  5662
# Loss: 196.7504927615489
# Training step:  5663
# Loss: 196.74936256312154
# Training step:  5664
# Loss: 196.75048752303644
# Training step:  5665
# Loss: 196.74935898705118
# Training step:  5666
# Loss: 196.7504823097459
# Training step:  5667
# Loss: 196.7493554437683
# Training step:  5668
# Loss: 196.7504770992682
# Training step:  5669
# Loss: 196.74935189529378
# Training step:  5670
# Loss: 196.7503368627598
# Training step:  5671
# Loss: 196.7493532105187
# Training step:  5672
# Loss: 196.7503317980868
# Training step:  5673
# Loss: 196.74934958078975
# Training step:  5674
# Loss: 196.7503267449428
# Training step:  5675
# Loss: 196.7493459793687
# Training step:  5676
# Loss: 196.75032169718813
# Training step:  5677
# Loss: 196.749342364389
# Training step:  5678
# Loss: 196.75031667405233
# Training step:  5679
# Loss: 196.749338789067
# Training step:  5680
# Loss: 196.75031166214444
# Training step:  5681
# Loss: 196.74933521403034
# Training step:  5682
# Loss: 196.75030665725203
# Training step:  5683
# Loss: 196.74933165338675
# Training step:  5684
# Loss: 196.7503016751739
# Training step:  5685
# Loss: 196.74932809865817
# Training step:  5686
# Loss: 196.75029670263018
# Training step:  5687
# Loss: 196.74932454913264
# Training step:  5688
# Loss: 196.75029174409286
# Training step:  5689
# Loss: 196.7493210212973
# Training step:  5690
# Loss: 196.7502867986115
# Training step:  5691
# Loss: 196.74931751328324
# Training step:  5692
# Loss: 196.75028186775177
# Training step:  5693
# Loss: 196.74931400318786
# Training step:  5694
# Loss: 196.75027694840773
# Training step:  5695
# Loss: 196.74930975550518
# Training step:  5696
# Loss: 196.75027207202749
# Training step:  5697
# Loss: 196.74930627397237
# Training step:  5698
# Loss: 196.75026717519572
# Training step:  5699
# Loss: 196.74930281030817
# Training step:  5700
# Loss: 196.75026230121114
# Training step:  5701
# Loss: 196.74929933150023
# Training step:  5702
# Loss: 196.7502574372542
# Training step:  5703
# Loss: 196.7492958926323
# Training step:  5704
# Loss: 196.75025258444677
# Training step:  5705
# Loss: 196.74929245126663
# Training step:  5706
# Loss: 196.75024774857766
# Training step:  5707
# Loss: 196.74928896502288
# Training step:  5708
# Loss: 196.75024291861604
# Training step:  5709
# Loss: 196.74928553238408
# Training step:  5710
# Loss: 196.75023811122188
# Training step:  5711
# Loss: 196.74928213907168
# Training step:  5712
# Loss: 196.75023331388005
# Training step:  5713
# Loss: 196.74927874521612
# Training step:  5714
# Loss: 196.75022852681022
# Training step:  5715
# Loss: 196.74927526371357
# Training step:  5716
# Loss: 196.75022375782171
# Training step:  5717
# Loss: 196.7492718743175
# Training step:  5718
# Loss: 196.75021899349753
# Training step:  5719
# Loss: 196.74926844632841
# Training step:  5720
# Loss: 196.7502142519833
# Training step:  5721
# Loss: 196.7492650993257
# Training step:  5722
# Loss: 196.75020952024408
# Training step:  5723
# Loss: 196.74926176874203
# Training step:  5724
# Loss: 196.7502047978503
# Training step:  5725
# Loss: 196.74925842602374
# Training step:  5726
# Loss: 196.75020009380808
# Training step:  5727
# Loss: 196.7492550729338
# Training step:  5728
# Loss: 196.7501953954177
# Training step:  5729
# Loss: 196.74925176924907
# Training step:  5730
# Loss: 196.75019071799647
# Training step:  5731
# Loss: 196.74924847739473
# Training step:  5732
# Loss: 196.75018604953095
# Training step:  5733
# Loss: 196.74924519395609
# Training step:  5734
# Loss: 196.75018139444143
# Training step:  5735
# Loss: 196.74924192155058
# Training step:  5736
# Loss: 196.75017675104786
# Training step:  5737
# Loss: 196.74923865940372
# Training step:  5738
# Loss: 196.7501721222222
# Training step:  5739
# Loss: 196.74923540887502
# Training step:  5740
# Loss: 196.75016750240655
# Training step:  5741
# Loss: 196.749232073252
# Training step:  5742
# Loss: 196.7501629008039
# Training step:  5743
# Loss: 196.749228837725
# Training step:  5744
# Loss: 196.75015830471958
# Training step:  5745
# Loss: 196.74922560471506
# Training step:  5746
# Loss: 196.75015372873634
# Training step:  5747
# Loss: 196.74922231811843
# Training step:  5748
# Loss: 196.75014916128475
# Training step:  5749
# Loss: 196.74921911343404
# Training step:  5750
# Loss: 196.75014460802365
# Training step:  5751
# Loss: 196.74921590882423
# Training step:  5752
# Loss: 196.75014006336744
# Training step:  5753
# Loss: 196.74921273083967
# Training step:  5754
# Loss: 196.75013553664422
# Training step:  5755
# Loss: 196.74920956269204
# Training step:  5756
# Loss: 196.7501310160126
# Training step:  5757
# Loss: 196.74920640526977
# Training step:  5758
# Loss: 196.75012651444584
# Training step:  5759
# Loss: 196.74920323511625
# Training step:  5760
# Loss: 196.75012202035822
# Training step:  5761
# Loss: 196.7492000736064
# Training step:  5762
# Loss: 196.75011754231235
# Training step:  5763
# Loss: 196.74919695676124
# Training step:  5764
# Loss: 196.75011307003714
# Training step:  5765
# Loss: 196.74919383710687
# Training step:  5766
# Loss: 196.75010861784708
# Training step:  5767
# Loss: 196.74919063644919
# Training step:  5768
# Loss: 196.75010417471185
# Training step:  5769
# Loss: 196.74918749494253
# Training step:  5770
# Loss: 196.75009974330294
# Training step:  5771
# Loss: 196.74918441645733
# Training step:  5772
# Loss: 196.75009532407708
# Training step:  5773
# Loss: 196.74918128401077
# Training step:  5774
# Loss: 196.75009091677916
# Training step:  5775
# Loss: 196.74917822994058
# Training step:  5776
# Loss: 196.75008652183874
# Training step:  5777
# Loss: 196.74917517650192
# Training step:  5778
# Loss: 196.75008213809812
# Training step:  5779
# Loss: 196.7491721303541
# Training step:  5780
# Loss: 196.7500777676946
# Training step:  5781
# Loss: 196.7491690600639
# Training step:  5782
# Loss: 196.75007340673926
# Training step:  5783
# Loss: 196.74779159714467
# Training step:  5784
# Loss: 196.7469674320717
# Training step:  5785
# Loss: 196.7452056464851
# Training step:  5786
# Loss: 196.74517108781558
# Training step:  5787
# Loss: 196.743678449123
# Training step:  5788
# Loss: 196.74494922702183
# Training step:  5789
# Loss: 196.7436479027149
# Training step:  5790
# Loss: 196.74481104257683
# Training step:  5791
# Loss: 196.74362541580774
# Training step:  5792
# Loss: 196.74468205113376
# Training step:  5793
# Loss: 196.74361058037135
# Training step:  5794
# Loss: 196.74456205160277
# Training step:  5795
# Loss: 196.74360364143934
# Training step:  5796
# Loss: 196.74445083782294
# Training step:  5797
# Loss: 196.74312107881397
# Training step:  5798
# Loss: 196.74438866327418
# Training step:  5799
# Loss: 196.743105335685
# Training step:  5800
# Loss: 196.74427022697017
# Training step:  5801
# Loss: 196.7430969536141
# Training step:  5802
# Loss: 196.74416019418896
# Training step:  5803
# Loss: 196.7430957100328
# Training step:  5804
# Loss: 196.74415583807573
# Training step:  5805
# Loss: 196.74309292357805
# Training step:  5806
# Loss: 196.74415149725309
# Training step:  5807
# Loss: 196.74309014180548
# Training step:  5808
# Loss: 196.74414716258505
# Training step:  5809
# Loss: 196.743087340918
# Training step:  5810
# Loss: 196.74414284622827
# Training step:  5811
# Loss: 196.74308457916143
# Training step:  5812
# Loss: 196.74413853759626
# Training step:  5813
# Loss: 196.74308182118057
# Training step:  5814
# Loss: 196.74413424233728
# Training step:  5815
# Loss: 196.74307903886339
# Training step:  5816
# Loss: 196.74412995543034
# Training step:  5817
# Loss: 196.74307630929832
# Training step:  5818
# Loss: 196.74412568424128
# Training step:  5819
# Loss: 196.7430735852598
# Training step:  5820
# Loss: 196.74412141891645
# Training step:  5821
# Loss: 196.74307087045452
# Training step:  5822
# Loss: 196.74411717031168
# Training step:  5823
# Loss: 196.74306816541048
# Training step:  5824
# Loss: 196.7441129264442
# Training step:  5825
# Loss: 196.74306542732518
# Training step:  5826
# Loss: 196.74410868408197
# Training step:  5827
# Loss: 196.74306272592182
# Training step:  5828
# Loss: 196.74410446424307
# Training step:  5829
# Loss: 196.743060048561
# Training step:  5830
# Loss: 196.74410026099395
# Training step:  5831
# Loss: 196.74305732696496
# Training step:  5832
# Loss: 196.74409606171426
# Training step:  5833
# Loss: 196.74305467213944
# Training step:  5834
# Loss: 196.7440918726117
# Training step:  5835
# Loss: 196.743052027648
# Training step:  5836
# Loss: 196.74408769645277
# Training step:  5837
# Loss: 196.74304935189227
# Training step:  5838
# Loss: 196.74408352329598
# Training step:  5839
# Loss: 196.74304672667165
# Training step:  5840
# Loss: 196.74407937211174
# Training step:  5841
# Loss: 196.7430440840635
# Training step:  5842
# Loss: 196.7440752349996
# Training step:  5843
# Loss: 196.74304146879027
# Training step:  5844
# Loss: 196.74407109941183
# Training step:  5845
# Loss: 196.7430388630036
# Training step:  5846
# Loss: 196.7440669798354
# Training step:  5847
# Loss: 196.74303622071898
# Training step:  5848
# Loss: 196.7423840524719
# Training step:  5849
# Loss: 196.74151096362976
# Training step:  5850
# Loss: 196.74223356067853
# Training step:  5851
# Loss: 196.74024561754408
# Training step:  5852
# Loss: 196.7394788032925
# Training step:  5853
# Loss: 196.73765554477708
# Training step:  5854
# Loss: 196.73649590649072
# Training step:  5855
# Loss: 196.7346107112761
# Training step:  5856
# Loss: 196.73352568602175
# Training step:  5857
# Loss: 196.73126178386866
# Training step:  5858
# Loss: 196.72969351246223
# Training step:  5859
# Loss: 196.72882487693653
# Training step:  5860
# Loss: 196.72925137428982
# Training step:  5861
# Loss: 196.72752498538466
# Training step:  5862
# Loss: 196.7265103622785
# Training step:  5863
# Loss: 196.72616305643936
# Training step:  5864
# Loss: 196.72624037804727
# Training step:  5865
# Loss: 196.7248479318689
# Training step:  5866
# Loss: 196.726164708173
# Training step:  5867
# Loss: 196.7248334385322
# Training step:  5868
# Loss: 196.7260630681439
# Training step:  5869
# Loss: 196.7248246130212
# Training step:  5870
# Loss: 196.7259681273927
# Training step:  5871
# Loss: 196.72482147628742
# Training step:  5872
# Loss: 196.72596404107006
# Training step:  5873
# Loss: 196.7248190782474
# Training step:  5874
# Loss: 196.72595998439644
# Training step:  5875
# Loss: 196.7248166988591
# Training step:  5876
# Loss: 196.72595593328083
# Training step:  5877
# Loss: 196.7248143107721
# Training step:  5878
# Loss: 196.7259518937768
# Training step:  5879
# Loss: 196.72481191781338
# Training step:  5880
# Loss: 196.72594786009168
# Training step:  5881
# Loss: 196.72480957077744
# Training step:  5882
# Loss: 196.72594384250237
# Training step:  5883
# Loss: 196.7248071522912
# Training step:  5884
# Loss: 196.7259398274908
# Training step:  5885
# Loss: 196.7248047954821
# Training step:  5886
# Loss: 196.72593583369186
# Training step:  5887
# Loss: 196.7248024667673
# Training step:  5888
# Loss: 196.72593183828553
# Training step:  5889
# Loss: 196.72480013507672
# Training step:  5890
# Loss: 196.72592786594214
# Training step:  5891
# Loss: 196.72479774195475
# Training step:  5892
# Loss: 196.72592389684655
# Training step:  5893
# Loss: 196.72479542659056
# Training step:  5894
# Loss: 196.7259199405457
# Training step:  5895
# Loss: 196.7247931016368
# Training step:  5896
# Loss: 196.72591599427778
# Training step:  5897
# Loss: 196.72479080128704
# Training step:  5898
# Loss: 196.72591205190042
# Training step:  5899
# Loss: 196.72478853034139
# Training step:  5900
# Loss: 196.72590812821866
# Training step:  5901
# Loss: 196.72478624340184
# Training step:  5902
# Loss: 196.72590421826857
# Training step:  5903
# Loss: 196.72478397258445
# Training step:  5904
# Loss: 196.72590030781396
# Training step:  5905
# Loss: 196.7247816694021
# Training step:  5906
# Loss: 196.72589641842748
# Training step:  5907
# Loss: 196.72477940515742
# Training step:  5908
# Loss: 196.72589253013464
# Training step:  5909
# Loss: 196.7247771633144
# Training step:  5910
# Loss: 196.72588866040218
# Training step:  5911
# Loss: 196.72477492804597
# Training step:  5912
# Loss: 196.7258847868002
# Training step:  5913
# Loss: 196.7247726700988
# Training step:  5914
# Loss: 196.72588093920254
# Training step:  5915
# Loss: 196.7247704518449
# Training step:  5916
# Loss: 196.72587709684126
# Training step:  5917
# Loss: 196.72476819002907
# Training step:  5918
# Loss: 196.72587326288038
# Training step:  5919
# Loss: 196.72476596928107
# Training step:  5920
# Loss: 196.7258694408887
# Training step:  5921
# Loss: 196.7247637614736
# Training step:  5922
# Loss: 196.72586562427477
# Training step:  5923
# Loss: 196.72476157236505
# Training step:  5924
# Loss: 196.72586182282362
# Training step:  5925
# Loss: 196.72475936327868
# Training step:  5926
# Loss: 196.72585803280538
# Training step:  5927
# Loss: 196.72475713034308
# Training step:  5928
# Loss: 196.72585424406273
# Training step:  5929
# Loss: 196.72475497038198
# Training step:  5930
# Loss: 196.7258504754799
# Training step:  5931
# Loss: 196.7247527956954
# Training step:  5932
# Loss: 196.72584670768603
# Training step:  5933
# Loss: 196.72475064364633
# Training step:  5934
# Loss: 196.72576424394055
# Training step:  5935
# Loss: 196.7247509566141
# Training step:  5936
# Loss: 196.72576055348503
# Training step:  5937
# Loss: 196.72474873709783
# Training step:  5938
# Loss: 196.72575688651605
# Training step:  5939
# Loss: 196.72474641243912
# Training step:  5940
# Loss: 196.7257532245671
# Training step:  5941
# Loss: 196.72474424056273
# Training step:  5942
# Loss: 196.72574956645127
# Training step:  5943
# Loss: 196.724742047907
# Training step:  5944
# Loss: 196.72574592521207
# Training step:  5945
# Loss: 196.72473987489386
# Training step:  5946
# Loss: 196.7257422956975
# Training step:  5947
# Loss: 196.72473772324793
# Training step:  5948
# Loss: 196.72573866419754
# Training step:  5949
# Loss: 196.72473557408992
# Training step:  5950
# Loss: 196.72573505513293
# Training step:  5951
# Loss: 196.7247334071584
# Training step:  5952
# Loss: 196.72573145026888
# Training step:  5953
# Loss: 196.7247312711834
# Training step:  5954
# Loss: 196.7257278508146
# Training step:  5955
# Loss: 196.72472914291657
# Training step:  5956
# Loss: 196.72572426697872
# Training step:  5957
# Loss: 196.7247270225971
# Training step:  5958
# Loss: 196.7257206943077
# Training step:  5959
# Loss: 196.72472487983262
# Training step:  5960
# Loss: 196.72571711966987
# Training step:  5961
# Loss: 196.72472276353528
# Training step:  5962
# Loss: 196.72571356763717
# Training step:  5963
# Loss: 196.72472053554938
# Training step:  5964
# Loss: 196.72571002106713
# Training step:  5965
# Loss: 196.72471843849837
# Training step:  5966
# Loss: 196.72570647797625
# Training step:  5967
# Loss: 196.72471634239812
# Training step:  5968
# Loss: 196.72570295037437
# Training step:  5969
# Loss: 196.72471426210925
# Training step:  5970
# Loss: 196.72569943327267
# Training step:  5971
# Loss: 196.72471213582426
# Training step:  5972
# Loss: 196.72569591076137
# Training step:  5973
# Loss: 196.72471007115092
# Training step:  5974
# Loss: 196.724865104897
# Training step:  5975
# Loss: 196.72368256504808
# Training step:  5976
# Loss: 196.72282508369688
# Training step:  5977
# Loss: 196.72148337069498
# Training step:  5978
# Loss: 196.72046555552072
# Training step:  5979
# Loss: 196.71871811224327
# Training step:  5980
# Loss: 196.7181371995865
# Training step:  5981
# Loss: 196.717822356141
# Training step:  5982
# Loss: 196.71793753247698
# Training step:  5983
# Loss: 196.7167750813967
# Training step:  5984
# Loss: 196.7165550236454
# Training step:  5985
# Loss: 196.71586581149003
# Training step:  5986
# Loss: 196.71654162256482
# Training step:  5987
# Loss: 196.71586354222822
# Training step:  5988
# Loss: 196.71653840904924
# Training step:  5989
# Loss: 196.71586132378724
# Training step:  5990
# Loss: 196.71653520063887
# Training step:  5991
# Loss: 196.7158590678037
# Training step:  5992
# Loss: 196.71653200642376
# Training step:  5993
# Loss: 196.71585686170894
# Training step:  5994
# Loss: 196.71652882179285
# Training step:  5995
# Loss: 196.71585464562017
# Training step:  5996
# Loss: 196.71652563755057
# Training step:  5997
# Loss: 196.7158524432613
# Training step:  5998
# Loss: 196.7165224720593
# Training step:  5999
# Loss: 196.71585025852858
# Loss_min: tensor(196.7159, grad_fn=<MulBackward0>)

# %%
# def load_model_predict(model_city_date_path, data, city_name='深圳',c='confirmed'):
#     model_pt = os.path.join(model_city_date_path,'model.pt')
#     model = torch.load(model_pt)
#     I = model.I_tensor_cur
#     R = model.R_tensor_cur
#     D = model.D_tensor_cur
#     I_pred_old = (I.detach().numpy()).astype(np.int)
#     R_pred_old = (R.detach().numpy()).astype(np.int)
#     D_pred_old = (D.detach().numpy()).astype(np.int)

#     confirm_pred = cal_acc_confirm(I_pred_old,R_pred_old,D_pred_old)
#     confirm_origin = get_data_acc_confirm(data,c=c)
#     print(confirm_origin)
#     plot_daily_acc(data, confirm_origin, confirm_pred, city=city_name)


#     new_confirm = cal_new_confirm(np.array(data['I']),np.array(data['cured']),np.array(data['dead']))
#     cal_acc_confirm(I_pred_old,R_pred_old,D_pred_old)
#     new_confirm_pred = cal_new_confirm(I_pred_old,R_pred_old,D_pred_old)

#     S_pred_tensor, I_pred_tensor, E_pred_tensor, R_pred_tensor, D_pred_tensor = model.pred(pred_date_len = 5)
#     I_pred_new = (I_pred_tensor.detach().numpy()).astype(np.int)
#     R_pred_new = (R_pred_tensor.detach().numpy()).astype(np.int)
#     D_pred_new = (D_pred_tensor.detach().numpy()).astype(np.int)
#     I_pred_total = np.concatenate((I_pred_old,I_pred_new),axis=0)
#     R_pred_total = np.concatenate((R_pred_old,R_pred_new),axis=0)
#     D_pred_total = np.concatenate((D_pred_old,D_pred_new),axis=0)

#     confirm_pred = cal_acc_confirm(I_pred_total,R_pred_total,D_pred_total)
#     confirm_origin = get_data_acc_confirm(data,c=c)
#     plot_daily_acc(data, confirm_origin, confirm_pred, city=city_name, pred_date_len=5)

#     new_confirm_pred_total = cal_new_confirm(I_pred_total,R_pred_total,D_pred_total)
#     new_confirm_pred_total

#     plot_daily_new(data, new_confirm, new_confirm_pred_total, city=city_name, pred_date_len=5)

# %%
model_city_date_path = 'models/shenzhen/02-10'

# %%
param = {'beta_model_0': 0.022657147212237192, 'gamma_2_model_0': 0.046245946644636965, 'N_model_0': 0, 'theta_model_0': 0.0017369414764662925}

# %%
load_model_predict(model_city_date_path, data_sz, city_name='深圳')
# Out:
# [ 36  49  63  86 110 170 196 226 269 289 314 334 351 364 368 375]
# confirm_pred [ 36 136 136 136 136 173 198 229 267 289 315 333 350 363 367 374 396 417
#  439 462 486]

# %%
data_wh = read_data('./ncov/data/wuhan_截至0209_24时.csv')
data_wh
# Out:
#     confirmed  suspected  dead  cured       time      I
# 0         258          0     6     25 2020-01-20    227
# 1         363          0     9     28 2020-01-21    326
# 2         425          0    17     28 2020-01-22    380
# 3         495          0    23     31 2020-01-23    441
# 4         572          0    38     32 2020-01-24    502
# 5         618          0    45     40 2020-01-25    533
# 6         698          0    63     42 2020-01-26    593
# 7        1590          0    85     45 2020-01-27   1460
# 8        1905          0   104     78 2020-01-28   1723
# 9        2261          0   129     85 2020-01-29   2047
# 10       2639          0   159    106 2020-01-30   2374
# 11       3215          0   192    142 2020-01-31   2881
# 12       4109          0   224    174 2020-02-01   3711
# 13       5142          0   265    227 2020-02-02   4650
# 14       6384          0   313    306 2020-02-03   5765
# 15       8351          0   362    374 2020-02-04   7615
# 16      10117          0   414    459 2020-02-05   9244
# 17      11618          0   478    542 2020-02-06  10598
# 18      13603          0   545    747 2020-02-07  12311
# 19      14982          0   608    877 2020-02-08  13497
# 20      16902          0   681   1045 2020-02-09  15176

# %%
model_city_date_path = make_dir('wuhan','02-09')
features=['I', 'cured','dead']
I_init = float(data_wh['I'].iloc[0])
R_init = float(data_wh['cured'].iloc[0])
D_init = float(data_wh['dead'].iloc[0])
N = 2870000.
S,I,E,R,D = train(data_wh, model_city_date_path, N=N, I_init=I_init, R_init=R_init, D_init=D_init, features=features, max_epoches=2000)
# Out:
# s: 200244.22229081442
# Training step:  1562
# Loss: 262643.150237525
# Training step:  1563
# Loss: 200240.49017761837
# Training step:  1564
# Loss: 262639.5803193018
# Training step:  1565
# Loss: 200236.76408632394
# Training step:  1566
# Loss: 262636.0161326938
# Training step:  1567
# Loss: 200233.0440004545
# Training step:  1568
# Loss: 262632.45766228746
# Training step:  1569
# Loss: 200229.32990359957
# Training step:  1570
# Loss: 262628.9048927113
# Training step:  1571
# Loss: 200225.62177940964
# Training step:  1572
# Loss: 262625.3578086366
# Training step:  1573
# Loss: 200221.91961160663
# Training step:  1574
# Loss: 262621.81639487157
# Training step:  1575
# Loss: 200218.2233840037
# Training step:  1576
# Loss: 262618.28063618735
# Training step:  1577
# Loss: 200214.5330803833
# Training step:  1578
# Loss: 262614.75051738333
# Training step:  1579
# Loss: 200210.84868466324
# Training step:  1580
# Loss: 262611.2260234673
# Training step:  1581
# Loss: 200207.17018088582
# Training step:  1582
# Loss: 262607.7071394668
# Training step:  1583
# Loss: 200203.49755304854
# Training step:  1584
# Loss: 262604.19385035546
# Training step:  1585
# Loss: 200199.83078523437
# Training step:  1586
# Loss: 262600.6861412465
# Training step:  1587
# Loss: 200196.169861639
# Training step:  1588
# Loss: 262597.1839973473
# Training step:  1589
# Loss: 200192.51476647385
# Training step:  1590
# Loss: 262593.6874038362
# Training step:  1591
# Loss: 200188.86548401864
# Training step:  1592
# Loss: 262590.196345988
# Training step:  1593
# Loss: 200185.22199859866
# Training step:  1594
# Loss: 262586.71080908383
# Training step:  1595
# Loss: 200181.58429462212
# Training step:  1596
# Loss: 262583.2307785647
# Training step:  1597
# Loss: 200177.9523565818
# Training step:  1598
# Loss: 262579.7562398948
# Training step:  1599
# Loss: 200174.32616904337
# Training step:  1600
# Loss: 262576.2871786458
# Training step:  1601
# Loss: 200170.7057166046
# Training step:  1602
# Loss: 262572.82358033094
# Training step:  1603
# Loss: 200167.09098386657
# Training step:  1604
# Loss: 262569.3654305041
# Training step:  1605
# Loss: 200163.4819555396
# Training step:  1606
# Loss: 262565.91271486605
# Training step:  1607
# Loss: 200159.87861640996
# Training step:  1608
# Loss: 262562.4654191543
# Training step:  1609
# Loss: 200156.28095130844
# Training step:  1610
# Loss: 262559.0235291702
# Training step:  1611
# Loss: 200152.688945147
# Training step:  1612
# Loss: 262555.5870307648
# Training step:  1613
# Loss: 200149.10258285995
# Training step:  1614
# Loss: 262552.1559097961
# Training step:  1615
# Loss: 200145.52184944018
# Training step:  1616
# Loss: 262548.7301522283
# Training step:  1617
# Loss: 200141.94672998227
# Training step:  1618
# Loss: 262545.309744073
# Training step:  1619
# Loss: 200138.37720956837
# Training step:  1620
# Loss: 262541.89467132685
# Training step:  1621
# Loss: 200134.8132733928
# Training step:  1622
# Loss: 262538.4849201508
# Training step:  1623
# Loss: 200131.2549067031
# Training step:  1624
# Loss: 262535.080476693
# Training step:  1625
# Loss: 200127.7020947742
# Training step:  1626
# Loss: 262531.6813271328
# Training step:  1627
# Loss: 200124.15482293855
# Training step:  1628
# Loss: 262528.28745772695
# Training step:  1629
# Loss: 200120.61307661474
# Training step:  1630
# Loss: 262524.89885481587
# Training step:  1631
# Loss: 200117.07684125807
# Training step:  1632
# Loss: 262521.51550475607
# Training step:  1633
# Loss: 200113.5461024013
# Training step:  1634
# Loss: 262518.13739399525
# Training step:  1635
# Loss: 200110.02084560442
# Training step:  1636
# Loss: 262514.7645089782
# Training step:  1637
# Loss: 200106.5010565066
# Training step:  1638
# Loss: 262511.396836269
# Training step:  1639
# Loss: 200102.98672080887
# Training step:  1640
# Loss: 262508.03436246986
# Training step:  1641
# Loss: 200099.47782425748
# Training step:  1642
# Loss: 262504.67707416846
# Training step:  1643
# Loss: 200095.9743525789
# Training step:  1644
# Loss: 262501.32495795586
# Training step:  1645
# Loss: 200092.47629160664
# Training step:  1646
# Loss: 262497.97800056986
# Training step:  1647
# Loss: 200088.98362724175
# Training step:  1648
# Loss: 262494.6361887807
# Training step:  1649
# Loss: 200085.49634544415
# Training step:  1650
# Loss: 262491.29950946104
# Training step:  1651
# Loss: 200082.014432264
# Training step:  1652
# Loss: 262487.96794953995
# Training step:  1653
# Loss: 200078.53787376508
# Training step:  1654
# Loss: 262484.6414959222
# Training step:  1655
# Loss: 200075.0666560302
# Training step:  1656
# Loss: 262481.32013552537
# Training step:  1657
# Loss: 200071.60076519434
# Training step:  1658
# Loss: 262478.0038553468
# Training step:  1659
# Loss: 200068.14018746532
# Training step:  1660
# Loss: 262474.6926424509
# Training step:  1661
# Loss: 200064.68490911683
# Training step:  1662
# Loss: 262471.38648398785
# Training step:  1663
# Loss: 200061.23491648072
# Training step:  1664
# Loss: 262468.0853671163
# Training step:  1665
# Loss: 200057.790195908
# Training step:  1666
# Loss: 262464.789279036
# Training step:  1667
# Loss: 200054.35073385545
# Training step:  1668
# Loss: 262461.49820707995
# Training step:  1669
# Loss: 200050.91651677297
# Training step:  1670
# Loss: 262458.212138457
# Training step:  1671
# Loss: 200047.487531151
# Training step:  1672
# Loss: 262454.9310605435
# Training step:  1673
# Loss: 200044.06376357801
# Training step:  1674
# Loss: 262451.6549607338
# Training step:  1675
# Loss: 200040.6452006744
# Training step:  1676
# Loss: 262448.3838264851
# Training step:  1677
# Loss: 200037.23182909712
# Training step:  1678
# Loss: 262445.117645267
# Training step:  1679
# Loss: 200033.8236355585
# Training step:  1680
# Loss: 262441.8564045887
# Training step:  1681
# Loss: 200030.42060682108
# Training step:  1682
# Loss: 262438.60009206575
# Training step:  1683
# Loss: 200027.02272972636
# Training step:  1684
# Loss: 262435.3486953497
# Training step:  1685
# Loss: 200023.62999114205
# Training step:  1686
# Loss: 262432.10220209806
# Training step:  1687
# Loss: 200020.2423779631
# Training step:  1688
# Loss: 262428.8606000046
# Training step:  1689
# Loss: 200016.85987715158
# Training step:  1690
# Loss: 262425.62387684855
# Training step:  1691
# Loss: 200013.4824757264
# Training step:  1692
# Loss: 262422.39202044107
# Training step:  1693
# Loss: 200010.1101607349
# Training step:  1694
# Loss: 262419.1650186117
# Training step:  1695
# Loss: 200006.74291929565
# Training step:  1696
# Loss: 262415.9428593028
# Training step:  1697
# Loss: 200003.380738559
# Training step:  1698
# Loss: 262412.725530417
# Training step:  1699
# Loss: 200000.02360571685
# Training step:  1700
# Loss: 262409.5130199356
# Training step:  1701
# Loss: 199996.6715079995
# Training step:  1702
# Loss: 262406.30531586584
# Training step:  1703
# Loss: 199993.32443271944
# Training step:  1704
# Loss: 262403.10240633285
# Training step:  1705
# Loss: 199989.9823672268
# Training step:  1706
# Loss: 262399.9042794173
# Training step:  1707
# Loss: 199986.6452988609
# Training step:  1708
# Loss: 262396.71092320903
# Training step:  1709
# Loss: 199983.31321506127
# Training step:  1710
# Loss: 262393.522325972
# Training step:  1711
# Loss: 199979.98610331916
# Training step:  1712
# Loss: 262390.33847592055
# Training step:  1713
# Loss: 199976.66395114668
# Training step:  1714
# Loss: 262387.1593613635
# Training step:  1715
# Loss: 199973.34674615084
# Training step:  1716
# Loss: 262383.98497066664
# Training step:  1717
# Loss: 199970.03447593472
# Training step:  1718
# Loss: 262380.8152921808
# Training step:  1719
# Loss: 199966.72712815733
# Training step:  1720
# Loss: 262377.65031428984
# Training step:  1721
# Loss: 199963.4246904711
# Training step:  1722
# Loss: 262374.49002537184
# Training step:  1723
# Loss: 199960.1271506214
# Training step:  1724
# Loss: 262371.33441395755
# Training step:  1725
# Loss: 199956.83449642497
# Training step:  1726
# Loss: 262368.18346862606
# Training step:  1727
# Loss: 199953.54671574815
# Training step:  1728
# Loss: 262365.0371779697
# Training step:  1729
# Loss: 199950.26379643835
# Training step:  1730
# Loss: 262361.89553053025
# Training step:  1731
# Loss: 199946.98572640226
# Training step:  1732
# Loss: 262358.758514984
# Training step:  1733
# Loss: 199943.7124936269
# Training step:  1734
# Loss: 262355.6261200347
# Training step:  1735
# Loss: 199940.44408607171
# Training step:  1736
# Loss: 262352.4983343187
# Training step:  1737
# Loss: 199937.18049180316
# Training step:  1738
# Loss: 262349.3751467222
# Training step:  1739
# Loss: 199933.92169895736
# Training step:  1740
# Loss: 262346.2565460539
# Training step:  1741
# Loss: 199930.66769564975
# Training step:  1742
# Loss: 262343.14252113004
# Training step:  1743
# Loss: 199927.41847002177
# Training step:  1744
# Loss: 262340.0330608068
# Training step:  1745
# Loss: 199924.17401034365
# Training step:  1746
# Loss: 262336.9281541294
# Training step:  1747
# Loss: 199920.93430485012
# Training step:  1748
# Loss: 262333.8277899355
# Training step:  1749
# Loss: 199917.6993418457
# Training step:  1750
# Loss: 262330.73195733904
# Training step:  1751
# Loss: 199914.46910970236
# Training step:  1752
# Loss: 262327.6406453578
# Training step:  1753
# Loss: 199911.24359679405
# Training step:  1754
# Loss: 262324.55384308414
# Training step:  1755
# Loss: 199908.02279153705
# Training step:  1756
# Loss: 262321.4715395975
# Training step:  1757
# Loss: 199904.80668239552
# Training step:  1758
# Loss: 262318.3937240903
# Training step:  1759
# Loss: 199901.59525787403
# Training step:  1760
# Loss: 262315.3203857099
# Training step:  1761
# Loss: 199898.38850649883
# Training step:  1762
# Loss: 262312.2515137218
# Training step:  1763
# Loss: 199895.1864169192
# Training step:  1764
# Loss: 262309.1870974742
# Training step:  1765
# Loss: 199891.9889777514
# Training step:  1766
# Loss: 262306.1271262062
# Training step:  1767
# Loss: 199888.7961776307
# Training step:  1768
# Loss: 262303.07158925314
# Training step:  1769
# Loss: 199885.60800528325
# Training step:  1770
# Loss: 262300.020476035
# Training step:  1771
# Loss: 199882.42444947132
# Training step:  1772
# Loss: 262296.97377598565
# Training step:  1773
# Loss: 199879.24549897225
# Training step:  1774
# Loss: 262293.9314785214
# Training step:  1775
# Loss: 199876.0711426004
# Training step:  1776
# Loss: 262290.8935731402
# Training step:  1777
# Loss: 199872.90136921022
# Training step:  1778
# Loss: 262287.8600493557
# Training step:  1779
# Loss: 199869.73616773146
# Training step:  1780
# Loss: 262284.83089678455
# Training step:  1781
# Loss: 199866.5755270961
# Training step:  1782
# Loss: 262281.8061049727
# Training step:  1783
# Loss: 199863.4194362776
# Training step:  1784
# Loss: 262278.7856636039
# Training step:  1785
# Loss: 199860.26788433612
# Training step:  1786
# Loss: 262275.7695623794
# Training step:  1787
# Loss: 199857.12086031286
# Training step:  1788
# Loss: 262272.75779097324
# Training step:  1789
# Loss: 199853.97835330525
# Training step:  1790
# Loss: 262269.7503391428
# Training step:  1791
# Loss: 199850.84035243804
# Training step:  1792
# Loss: 262266.7471966561
# Training step:  1793
# Loss: 199847.70684690127
# Training step:  1794
# Loss: 262263.74835336476
# Training step:  1795
# Loss: 199844.57782589982
# Training step:  1796
# Loss: 262260.75379907235
# Training step:  1797
# Loss: 199841.4532786515
# Training step:  1798
# Loss: 262257.7635236559
# Training step:  1799
# Loss: 199838.33319446558
# Training step:  1800
# Loss: 262254.77751707163
# Training step:  1801
# Loss: 199835.2175626371
# Training step:  1802
# Loss: 262251.79576919693
# Training step:  1803
# Loss: 199832.1063725342
# Training step:  1804
# Loss: 262248.8182701206
# Training step:  1805
# Loss: 199828.9996135873
# Training step:  1806
# Loss: 262245.8450098384
# Training step:  1807
# Loss: 199825.89727518437
# Training step:  1808
# Loss: 262242.8759783372
# Training step:  1809
# Loss: 199822.79934677642
# Training step:  1810
# Loss: 262239.91116574436
# Training step:  1811
# Loss: 199819.70581791055
# Training step:  1812
# Loss: 262236.95056222455
# Training step:  1813
# Loss: 199816.61667810506
# Training step:  1814
# Loss: 262233.99415787106
# Training step:  1815
# Loss: 199813.53191692365
# Training step:  1816
# Loss: 262231.0419429005
# Training step:  1817
# Loss: 199810.45152400443
# Training step:  1818
# Loss: 262228.0939075656
# Training step:  1819
# Loss: 199807.3754889891
# Training step:  1820
# Loss: 262225.1500421207
# Training step:  1821
# Loss: 199804.3038015641
# Training step:  1822
# Loss: 262222.210336809
# Training step:  1823
# Loss: 199801.2364513905
# Training step:  1824
# Loss: 262219.2747819244
# Training step:  1825
# Loss: 199798.17342825182
# Training step:  1826
# Loss: 262216.34336787125
# Training step:  1827
# Loss: 199795.11472195495
# Training step:  1828
# Loss: 262213.41608506197
# Training step:  1829
# Loss: 199792.06032230155
# Training step:  1830
# Loss: 262210.4929238397
# Training step:  1831
# Loss: 199789.01021912938
# Training step:  1832
# Loss: 262207.5738746987
# Training step:  1833
# Loss: 199785.96440235426
# Training step:  1834
# Loss: 262204.65892811824
# Training step:  1835
# Loss: 199782.92286189436
# Training step:  1836
# Loss: 262201.7480746151
# Training step:  1837
# Loss: 199779.88558769404
# Training step:  1838
# Loss: 262198.8413047163
# Training step:  1839
# Loss: 199776.85256975814
# Training step:  1840
# Loss: 262195.9386090175
# Training step:  1841
# Loss: 199773.82379811065
# Training step:  1842
# Loss: 262193.03997811634
# Training step:  1843
# Loss: 199770.79926278177
# Training step:  1844
# Loss: 262190.1454026101
# Training step:  1845
# Loss: 199767.77895386796
# Training step:  1846
# Loss: 262187.25487318623
# Training step:  1847
# Loss: 199764.76286149546
# Training step:  1848
# Loss: 262184.36838055326
# Training step:  1849
# Loss: 199761.750975836
# Training step:  1850
# Loss: 262181.4859154662
# Training step:  1851
# Loss: 199758.74328707787
# Training step:  1852
# Loss: 262178.6074686544
# Training step:  1853
# Loss: 199755.7397854372
# Training step:  1854
# Loss: 262175.7330309448
# Training step:  1855
# Loss: 199752.74046119343
# Training step:  1856
# Loss: 262172.8625931581
# Training step:  1857
# Loss: 199749.74530462033
# Training step:  1858
# Loss: 262169.99614612
# Training step:  1859
# Loss: 199746.7543060136
# Training step:  1860
# Loss: 262167.13368069
# Training step:  1861
# Loss: 199743.76745574697
# Training step:  1862
# Loss: 262164.27518785023
# Training step:  1863
# Loss: 199740.78474423886
# Training step:  1864
# Loss: 262161.4206585361
# Training step:  1865
# Loss: 199737.8061618642
# Training step:  1866
# Loss: 262158.5700836528
# Training step:  1867
# Loss: 199734.83169905524
# Training step:  1868
# Loss: 262155.7234542198
# Training step:  1869
# Loss: 199731.86134633943
# Training step:  1870
# Loss: 262152.88076133933
# Training step:  1871
# Loss: 199728.89509421532
# Training step:  1872
# Loss: 262150.04199601087
# Training step:  1873
# Loss: 199725.93293321072
# Training step:  1874
# Loss: 262147.2071493253
# Training step:  1875
# Loss: 199722.97485391
# Training step:  1876
# Loss: 262144.3762124158
# Training step:  1877
# Loss: 199720.02084691444
# Training step:  1878
# Loss: 262141.54917641063
# Training step:  1879
# Loss: 199717.0709028454
# Training step:  1880
# Loss: 262138.72603248007
# Training step:  1881
# Loss: 199714.12501238435
# Training step:  1882
# Loss: 262135.90677182973
# Training step:  1883
# Loss: 199711.18316621098
# Training step:  1884
# Loss: 262133.09138570452
# Training step:  1885
# Loss: 199708.24535509094
# Training step:  1886
# Loss: 262130.27986539004
# Training step:  1887
# Loss: 199705.31156976888
# Training step:  1888
# Loss: 262127.47220216846
# Training step:  1889
# Loss: 199702.38180105048
# Training step:  1890
# Loss: 262124.66838739143
# Training step:  1891
# Loss: 199699.4560397669
# Training step:  1892
# Loss: 262121.86841239053
# Training step:  1893
# Loss: 199696.5342767282
# Training step:  1894
# Loss: 262119.07226846545
# Training step:  1895
# Loss: 199693.6165027888
# Training step:  1896
# Loss: 262116.2799470355
# Training step:  1897
# Loss: 199690.70270891092
# Training step:  1898
# Loss: 262113.49143961337
# Training step:  1899
# Loss: 199687.79288601704
# Training step:  1900
# Loss: 262110.7067375673
# Training step:  1901
# Loss: 199684.88702506514
# Training step:  1902
# Loss: 262107.92583242632
# Training step:  1903
# Loss: 199681.9851170699
# Training step:  1904
# Loss: 262105.14871571376
# Training step:  1905
# Loss: 199679.08715306295
# Training step:  1906
# Loss: 262102.37537896956
# Training step:  1907
# Loss: 199676.19312409617
# Training step:  1908
# Loss: 262099.60581372323
# Training step:  1909
# Loss: 199673.3030212124
# Training step:  1910
# Loss: 262096.84001155026
# Training step:  1911
# Loss: 199670.41683556506
# Training step:  1912
# Loss: 262094.07796412185
# Training step:  1913
# Loss: 199667.53455830677
# Training step:  1914
# Loss: 262091.31966310748
# Training step:  1915
# Loss: 199664.65618060587
# Training step:  1916
# Loss: 262088.5651001427
# Training step:  1917
# Loss: 199661.78169364468
# Training step:  1918
# Loss: 262085.81426691505
# Training step:  1919
# Loss: 199658.9110886587
# Training step:  1920
# Loss: 262083.0671551742
# Training step:  1921
# Loss: 199656.04435689448
# Training step:  1922
# Loss: 262080.32375663982
# Training step:  1923
# Loss: 199653.18148963666
# Training step:  1924
# Loss: 262077.58406310785
# Training step:  1925
# Loss: 199650.3224782075
# Training step:  1926
# Loss: 262074.84806640056
# Training step:  1927
# Loss: 199647.4673139556
# Training step:  1928
# Loss: 262072.1157583442
# Training step:  1929
# Loss: 199644.6159882313
# Training step:  1930
# Loss: 262069.3871307674
# Training step:  1931
# Loss: 199641.76849243834
# Training step:  1932
# Loss: 262066.66217560365
# Training step:  1933
# Loss: 199638.9248180371
# Training step:  1934
# Loss: 262063.94088478116
# Training step:  1935
# Loss: 199636.0849564579
# Training step:  1936
# Loss: 262061.22325019428
# Training step:  1937
# Loss: 199633.24889916388
# Training step:  1938
# Loss: 262058.5092637813
# Training step:  1939
# Loss: 199630.41663765497
# Training step:  1940
# Loss: 262055.7989175401
# Training step:  1941
# Loss: 199627.58816347114
# Training step:  1942
# Loss: 262053.0922034658
# Training step:  1943
# Loss: 199624.7634681505
# Training step:  1944
# Loss: 262050.38911357304
# Training step:  1945
# Loss: 199621.94254330455
# Training step:  1946
# Loss: 262047.68963999953
# Training step:  1947
# Loss: 199619.1253805695
# Training step:  1948
# Loss: 262044.9937748071
# Training step:  1949
# Loss: 199616.31197156722
# Training step:  1950
# Loss: 262042.30151010177
# Training step:  1951
# Loss: 199613.50230796976
# Training step:  1952
# Loss: 262039.6128380207
# Training step:  1953
# Loss: 199610.6963814713
# Training step:  1954
# Loss: 262036.9277507202
# Training step:  1955
# Loss: 199607.89418376886
# Training step:  1956
# Loss: 262034.2462403497
# Training step:  1957
# Loss: 199605.09570662852
# Training step:  1958
# Loss: 262031.5682991792
# Training step:  1959
# Loss: 199602.30094183277
# Training step:  1960
# Loss: 262028.89391941548
# Training step:  1961
# Loss: 199599.5098811612
# Training step:  1962
# Loss: 262026.22309330327
# Training step:  1963
# Loss: 199596.7225164229
# Training step:  1964
# Loss: 262023.55581307673
# Training step:  1965
# Loss: 199593.9388394589
# Training step:  1966
# Loss: 262020.89207108464
# Training step:  1967
# Loss: 199591.15884217853
# Training step:  1968
# Loss: 262018.2318596685
# Training step:  1969
# Loss: 199588.38251645898
# Training step:  1970
# Loss: 262015.57517114887
# Training step:  1971
# Loss: 199585.6098542299
# Training step:  1972
# Loss: 262012.92199790681
# Training step:  1973
# Loss: 199582.8408474488
# Training step:  1974
# Loss: 262010.27233238492
# Training step:  1975
# Loss: 199580.0754881165
# Training step:  1976
# Loss: 262007.62616699582
# Training step:  1977
# Loss: 199577.31376820448
# Training step:  1978
# Loss: 262004.98349415103
# Training step:  1979
# Loss: 199574.55567975366
# Training step:  1980
# Loss: 262002.34430637353
# Training step:  1981
# Loss: 199571.801214839
# Training step:  1982
# Loss: 261999.70859616302
# Training step:  1983
# Loss: 199569.05036550958
# Training step:  1984
# Loss: 261997.07635596985
# Training step:  1985
# Loss: 199566.3031238492
# Training step:  1986
# Loss: 261994.4475783334
# Training step:  1987
# Loss: 199563.5594819798
# Training step:  1988
# Loss: 261991.82225583438
# Training step:  1989
# Loss: 199560.81943209466
# Training step:  1990
# Loss: 261989.2003810948
# Training step:  1991
# Loss: 199558.0829663371
# Training step:  1992
# Loss: 261986.5819466652
# Training step:  1993
# Loss: 199555.35007691148
# Training step:  1994
# Loss: 261983.9669452171
# Training step:  1995
# Loss: 199552.62075605677
# Training step:  1996
# Loss: 261981.35536939613
# Training step:  1997
# Loss: 199549.894995995
# Training step:  1998
# Loss: 261978.74721183753
# Training step:  1999
# Loss: 199547.172788994
# Loss_min: tensor(24857.3718, grad_fn=<AddBackward0>)

# %%
model_city_date_path='models/wuhan/02-09'

# %%
param = {'beta_model_1': 0.039265121494126254, 'gamma_2_model_1': 0.012185829495883437, 'N_model_1': 0, 'theta_model_1': 0.029595901217760776}

# %%
load_model_predict(model_city_date_path, data_wh, N_cur=param['N_model_1'],beta=param['beta_model_1'],gamma_2=param['gamma_2_model_1'],theta=param['theta_model_1'], city_name='武汉')
# Out:
# [  258   363   425   495   572   618   698  1590  1905  2261  2639  3215
#   4109  5142  6384  8351 10117 11618 13603 14982 16902]

# %%
# param = {'beta_model_2': 0.03808052845960208, 'gamma_2_model_2': 0.011726751251695009, 'N_model_2': 59170000.21805534, 'theta_model_2': 0.003805129170338665}
# i=2
# for k in list(param.keys()):
#     old_key = k
#     new_key = k.replace(f'_model_{i}','')
#     param[new_key]=param.pop(old_key)
# param

# %%
def train_with_city_data(data, N, date, cityname='深圳',max_epoches=2000):
    city_pinyin = {'深圳':'shenzhen', '湖北':'hubei', '武汉':'wuhan', '全国':'china'}
    pinyin = city_pinyin[cityname]
    model_city_date_path = make_dir(pinyin,date)
    features=['I', 'cured','dead']
    I_init = float(data['I'].iloc[0])
    R_init = float(data['cured'].iloc[0])
    D_init = float(data['dead'].iloc[0])
    N = N
    S,I,E,R,D = train(data, model_city_date_path, N=N, I_init=I_init, R_init=R_init, D_init=D_init, features=features, max_epoches=max_epoches)
    return model_city_date_path

# %%
data_hubei = read_data('./ncov/data/hubei_截至0209_24时i.csv')
data_hubei
# Out:
#     confirmed  suspected  dead  cured  close_contact  \
# 0         270          0     6     25           1070
# 1         375          0     9     28           1181
# 2         444          0    17     28           2556
# 3         549          0    24     31           3653
# 4         729          0    39     32           5682
# 5        1052          0    52     42           7989
# 6        1423          0    76     44          10394
# 7        2714          0   100     47          16904
# 8        3554          0   125     80          22095
# 9        4586          0   162     90          28780
# 10       5806          0   204    116          35144
# 11       7153          0   249    166          41075
# 12       9074          0   294    215          48571
# 13      11177          0   350    295          56088
# 14      13522          0   414    396          68988
# 15      16678          0   479    520          81039
# 16      19665          0   549    633          90997
# 17      22112          0   618    817         101599
# 18      24953          0   699   1115         114044
# 19      27100      23638   780   1439         123827
# 20      29631      18438   871   1795         132555
#
#     under_medical_observation  quit_medical_observation       time      I
# 0                         331                       739 2020-01-20    239
# 1                         426                       755 2020-01-21    338
# 2                        1693                       863 2020-01-22    399
# 3                        2776                       877 2020-01-23    494
# 4                        4711                       971 2020-01-24    658
# 5                        6904                      1085 2020-01-25    958
# 6                        9103                      1291 2020-01-26   1303
# 7                       15559                      1345 2020-01-27   2567
# 8                       20366                      1729 2020-01-28   3349
# 9                       26632                      2148 2020-01-29   4334
# 10                      32340                      2804 2020-01-30   5486
# 11                      36838                      4237 2020-01-31   6738
# 12                      43121                      5450 2020-02-01   8565
# 13                      48171                      7917 2020-02-02  10532
# 14                      58544                     10444 2020-02-03  12712
# 15                      66764                     14275 2020-02-04  15679
# 16                      64127                     26870 2020-02-05  18483
# 17                      64057                     37542 2020-02-06  20677
# 18                      67802                     46242 2020-02-07  23139
# 19                      70438                     53389 2020-02-08  24881
# 20                      73127                     59428 2020-02-09  26965

# %%
# param = {'beta_model_2': 0.03808052845960208, 'gamma_2_model_2': 0.011726751251695009, 'N_model_2': 0, 'theta_model_2': 0.003805129170338665}

# %%
model_city_date_path = train_with_city_data(data_hubei,59170000.,'02-08','湖北')
# Out:
# 555
# Loss: 872839.330382037
# Training step:  1556
# Loss: 669415.1439158998
# Training step:  1557
# Loss: 872823.1480143704
# Training step:  1558
# Loss: 669398.6483449434
# Training step:  1559
# Loss: 872806.9988472472
# Training step:  1560
# Loss: 669382.186563009
# Training step:  1561
# Loss: 872790.8827756529
# Training step:  1562
# Loss: 669365.7584629584
# Training step:  1563
# Loss: 872774.7996951195
# Training step:  1564
# Loss: 669349.3639379631
# Training step:  1565
# Loss: 872758.7495012515
# Training step:  1566
# Loss: 669333.0028816931
# Training step:  1567
# Loss: 872742.7320904778
# Training step:  1568
# Loss: 669316.6751884097
# Training step:  1569
# Loss: 872726.7473596112
# Training step:  1570
# Loss: 669300.3807527468
# Training step:  1571
# Loss: 872710.7952058689
# Training step:  1572
# Loss: 669284.1194699481
# Training step:  1573
# Loss: 872694.8755271897
# Training step:  1574
# Loss: 669267.8912355811
# Training step:  1575
# Loss: 872678.9882214658
# Training step:  1576
# Loss: 669251.6959455821
# Training step:  1577
# Loss: 872663.1331872933
# Training step:  1578
# Loss: 669235.5334965546
# Training step:  1579
# Loss: 872647.310323899
# Training step:  1580
# Loss: 669219.4037855824
# Training step:  1581
# Loss: 872631.519530856
# Training step:  1582
# Loss: 669203.3067100262
# Training step:  1583
# Loss: 872615.7607079457
# Training step:  1584
# Loss: 669187.2421677051
# Training step:  1585
# Loss: 872600.0337555149
# Training step:  1586
# Loss: 669171.210056958
# Training step:  1587
# Loss: 872584.3385744245
# Training step:  1588
# Loss: 669155.2102765639
# Training step:  1589
# Loss: 872568.6750658937
# Training step:  1590
# Loss: 669139.2427257284
# Training step:  1591
# Loss: 872553.0431315859
# Training step:  1592
# Loss: 669123.3073040468
# Training step:  1593
# Loss: 872537.442673508
# Training step:  1594
# Loss: 669107.4039116162
# Training step:  1595
# Loss: 872521.8735942849
# Training step:  1596
# Loss: 669091.5324489922
# Training step:  1597
# Loss: 872506.3357968132
# Training step:  1598
# Loss: 669075.6928171804
# Training step:  1599
# Loss: 872490.82918474
# Training step:  1600
# Loss: 669059.884917653
# Training step:  1601
# Loss: 872475.3536617431
# Training step:  1602
# Loss: 669044.1086521379
# Training step:  1603
# Loss: 872459.9091319522
# Training step:  1604
# Loss: 669028.363922778
# Training step:  1605
# Loss: 872444.4954998562
# Training step:  1606
# Loss: 669012.6506323181
# Training step:  1607
# Loss: 872429.1126707066
# Training step:  1608
# Loss: 668996.9686838839
# Training step:  1609
# Loss: 872413.7605499866
# Training step:  1610
# Loss: 668981.3179810536
# Training step:  1611
# Loss: 872398.4390435881
# Training step:  1612
# Loss: 668965.6984276831
# Training step:  1613
# Loss: 872383.1480576715
# Training step:  1614
# Loss: 668950.1099281192
# Training step:  1615
# Loss: 872367.8874989976
# Training step:  1616
# Loss: 668934.5523871308
# Training step:  1617
# Loss: 872352.6572745015
# Training step:  1618
# Loss: 668919.0257097803
# Training step:  1619
# Loss: 872337.4572917272
# Training step:  1620
# Loss: 668903.5298017908
# Training step:  1621
# Loss: 872322.2874585823
# Training step:  1622
# Loss: 668888.0645689702
# Training step:  1623
# Loss: 872307.1476831882
# Training step:  1624
# Loss: 668872.6299178912
# Training step:  1625
# Loss: 872292.037874538
# Training step:  1626
# Loss: 668857.2257552523
# Training step:  1627
# Loss: 872276.957941335
# Training step:  1628
# Loss: 668841.8519881585
# Training step:  1629
# Loss: 872261.907793107
# Training step:  1630
# Loss: 668826.5085243068
# Training step:  1631
# Loss: 872246.8873398567
# Training step:  1632
# Loss: 668811.195271631
# Training step:  1633
# Loss: 872231.8964916349
# Training step:  1634
# Loss: 668795.9121385728
# Training step:  1635
# Loss: 872216.9351592304
# Training step:  1636
# Loss: 668780.6590338215
# Training step:  1637
# Loss: 872202.0032533862
# Training step:  1638
# Loss: 668765.4358664886
# Training step:  1639
# Loss: 872187.1006855635
# Training step:  1640
# Loss: 668750.2425461748
# Training step:  1641
# Loss: 872172.2273674828
# Training step:  1642
# Loss: 668735.0789827335
# Training step:  1643
# Loss: 872157.3832112056
# Training step:  1644
# Loss: 668719.945086482
# Training step:  1645
# Loss: 872142.5681292143
# Training step:  1646
# Loss: 668704.8407681352
# Training step:  1647
# Loss: 872127.7820344894
# Training step:  1648
# Loss: 668689.7659387473
# Training step:  1649
# Loss: 872113.0248400638
# Training step:  1650
# Loss: 668674.7205096689
# Training step:  1651
# Loss: 872098.2964595867
# Training step:  1652
# Loss: 668659.704392779
# Training step:  1653
# Loss: 872083.5968069925
# Training step:  1654
# Loss: 668644.7175002369
# Training step:  1655
# Loss: 872068.9257966161
# Training step:  1656
# Loss: 668629.7597446099
# Training step:  1657
# Loss: 872054.2833431497
# Training step:  1658
# Loss: 668614.8310387959
# Training step:  1659
# Loss: 872039.6693615522
# Training step:  1660
# Loss: 668599.9312960759
# Training step:  1661
# Loss: 872025.0837672215
# Training step:  1662
# Loss: 668585.060430037
# Training step:  1663
# Loss: 872010.5264758156
# Training step:  1664
# Loss: 668570.2183547453
# Training step:  1665
# Loss: 871995.9974035398
# Training step:  1666
# Loss: 668555.4049845493
# Training step:  1667
# Loss: 871981.4964667747
# Training step:  1668
# Loss: 668540.6202342333
# Training step:  1669
# Loss: 871967.023582458
# Training step:  1670
# Loss: 668525.8640188961
# Training step:  1671
# Loss: 871952.5786676536
# Training step:  1672
# Loss: 668511.1362539278
# Training step:  1673
# Loss: 871938.1616397811
# Training step:  1674
# Loss: 668496.4368550635
# Training step:  1675
# Loss: 871923.7724166327
# Training step:  1676
# Loss: 668481.7657384755
# Training step:  1677
# Loss: 871909.4109163864
# Training step:  1678
# Loss: 668467.1228206205
# Training step:  1679
# Loss: 871895.0770575446
# Training step:  1680
# Loss: 668452.508018414
# Training step:  1681
# Loss: 871880.7707591212
# Training step:  1682
# Loss: 668437.9212490515
# Training step:  1683
# Loss: 871866.4919402018
# Training step:  1684
# Loss: 668423.3624300207
# Training step:  1685
# Loss: 871852.240520284
# Training step:  1686
# Loss: 668408.8314791715
# Training step:  1687
# Loss: 871838.0164192125
# Training step:  1688
# Loss: 668394.3283147205
# Training step:  1689
# Loss: 871823.8195571615
# Training step:  1690
# Loss: 668379.8528551889
# Training step:  1691
# Loss: 871809.649854623
# Training step:  1692
# Loss: 668365.4050194395
# Training step:  1693
# Loss: 871795.507232377
# Training step:  1694
# Loss: 668350.9847266859
# Training step:  1695
# Loss: 871781.3916116358
# Training step:  1696
# Loss: 668336.5918964917
# Training step:  1697
# Loss: 871767.3029138959
# Training step:  1698
# Loss: 668322.226448741
# Training step:  1699
# Loss: 871753.2410609727
# Training step:  1700
# Loss: 668307.8883036327
# Training step:  1701
# Loss: 871739.205974944
# Training step:  1702
# Loss: 668293.5773816368
# Training step:  1703
# Loss: 871725.1975782074
# Training step:  1704
# Loss: 668279.2936036834
# Training step:  1705
# Loss: 871711.2157936404
# Training step:  1706
# Loss: 668265.0368909073
# Training step:  1707
# Loss: 871697.2605442116
# Training step:  1708
# Loss: 668250.8071648092
# Training step:  1709
# Loss: 871683.3317533518
# Training step:  1710
# Loss: 668236.6043472654
# Training step:  1711
# Loss: 871669.4293448365
# Training step:  1712
# Loss: 668222.4283603741
# Training step:  1713
# Loss: 871655.5532425822
# Training step:  1714
# Loss: 668208.2791265991
# Training step:  1715
# Loss: 871641.7033708933
# Training step:  1716
# Loss: 668194.1565686688
# Training step:  1717
# Loss: 871627.879654431
# Training step:  1718
# Loss: 668180.0606097276
# Training step:  1719
# Loss: 871614.0820181475
# Training step:  1720
# Loss: 668165.9911732137
# Training step:  1721
# Loss: 871600.3103874155
# Training step:  1722
# Loss: 668151.9481828619
# Training step:  1723
# Loss: 871586.564687689
# Training step:  1724
# Loss: 668137.9315626322
# Training step:  1725
# Loss: 871572.8448447577
# Training step:  1726
# Loss: 668123.9412368515
# Training step:  1727
# Loss: 871559.1507848596
# Training step:  1728
# Loss: 668109.9771302573
# Training step:  1729
# Loss: 871545.4824344933
# Training step:  1730
# Loss: 668096.0391676506
# Training step:  1731
# Loss: 871531.8397200704
# Training step:  1732
# Loss: 668082.127274224
# Training step:  1733
# Loss: 871518.2225688179
# Training step:  1734
# Loss: 668068.2413755694
# Training step:  1735
# Loss: 871504.6309078996
# Training step:  1736
# Loss: 668054.3813974387
# Training step:  1737
# Loss: 871491.0646649724
# Training step:  1738
# Loss: 668040.5472660947
# Training step:  1739
# Loss: 871477.5237681149
# Training step:  1740
# Loss: 668026.7389079452
# Training step:  1741
# Loss: 871464.0081454039
# Training step:  1742
# Loss: 668012.9562497602
# Training step:  1743
# Loss: 871450.5177254553
# Training step:  1744
# Loss: 667999.1992185251
# Training step:  1745
# Loss: 871437.0524368833
# Training step:  1746
# Loss: 667985.4677415558
# Training step:  1747
# Loss: 871423.6122088261
# Training step:  1748
# Loss: 667971.7617464447
# Training step:  1749
# Loss: 871410.1969705519
# Training step:  1750
# Loss: 667958.0811610722
# Training step:  1751
# Loss: 871396.8066516625
# Training step:  1752
# Loss: 667944.4259136167
# Training step:  1753
# Loss: 871383.4411820844
# Training step:  1754
# Loss: 667930.7959325582
# Training step:  1755
# Loss: 871370.1004920048
# Training step:  1756
# Loss: 667917.1911466927
# Training step:  1757
# Loss: 871356.7845119651
# Training step:  1758
# Loss: 667903.6114850091
# Training step:  1759
# Loss: 871343.4931724658
# Training step:  1760
# Loss: 667890.0568767755
# Training step:  1761
# Loss: 871330.2264046749
# Training step:  1762
# Loss: 667876.5272516832
# Training step:  1763
# Loss: 871316.9841398668
# Training step:  1764
# Loss: 667863.0225395533
# Training step:  1765
# Loss: 871303.7663095072
# Training step:  1766
# Loss: 667849.5426705098
# Training step:  1767
# Loss: 871290.572845375
# Training step:  1768
# Loss: 667836.0875749812
# Training step:  1769
# Loss: 871277.4036796344
# Training step:  1770
# Loss: 667822.6571837094
# Training step:  1771
# Loss: 871264.2587445815
# Training step:  1772
# Loss: 667809.251427592
# Training step:  1773
# Loss: 871251.1379728565
# Training step:  1774
# Loss: 667795.8702380513
# Training step:  1775
# Loss: 871238.0412975637
# Training step:  1776
# Loss: 667782.5135465417
# Training step:  1777
# Loss: 871224.9686516401
# Training step:  1778
# Loss: 667769.1812847871
# Training step:  1779
# Loss: 871211.9199684552
# Training step:  1780
# Loss: 667755.8733847913
# Training step:  1781
# Loss: 871198.8951815877
# Training step:  1782
# Loss: 667742.58977884
# Training step:  1783
# Loss: 871185.8942249706
# Training step:  1784
# Loss: 667729.3303995691
# Training step:  1785
# Loss: 871172.9170329185
# Training step:  1786
# Loss: 667716.0951799469
# Training step:  1787
# Loss: 871159.9635399979
# Training step:  1788
# Loss: 667702.8840529933
# Training step:  1789
# Loss: 871147.0336806561
# Training step:  1790
# Loss: 667689.696952009
# Training step:  1791
# Loss: 871134.1273898553
# Training step:  1792
# Loss: 667676.5338106451
# Training step:  1793
# Loss: 871121.2446028161
# Training step:  1794
# Loss: 667663.3945628207
# Training step:  1795
# Loss: 871108.3852550954
# Training step:  1796
# Loss: 667650.2791427297
# Training step:  1797
# Loss: 871095.5492824159
# Training step:  1798
# Loss: 667637.187484776
# Training step:  1799
# Loss: 871082.7366206842
# Training step:  1800
# Loss: 667624.1195234921
# Training step:  1801
# Loss: 871069.94720589
# Training step:  1802
# Loss: 667611.0751937819
# Training step:  1803
# Loss: 871057.1809746983
# Training step:  1804
# Loss: 667598.0544310007
# Training step:  1805
# Loss: 871044.4378639394
# Training step:  1806
# Loss: 667585.0571704445
# Training step:  1807
# Loss: 871031.7178103152
# Training step:  1808
# Loss: 667572.0833477089
# Training step:  1809
# Loss: 871019.0207509781
# Training step:  1810
# Loss: 667559.1328987487
# Training step:  1811
# Loss: 871006.3466234783
# Training step:  1812
# Loss: 667546.2057597416
# Training step:  1813
# Loss: 870993.6953654364
# Training step:  1814
# Loss: 667533.3018670649
# Training step:  1815
# Loss: 870981.0669147682
# Training step:  1816
# Loss: 667520.4211573836
# Training step:  1817
# Loss: 870968.4612095641
# Training step:  1818
# Loss: 667507.563567529
# Training step:  1819
# Loss: 870955.8781882096
# Training step:  1820
# Loss: 667494.7290346842
# Training step:  1821
# Loss: 870943.3177893731
# Training step:  1822
# Loss: 667481.9174962225
# Training step:  1823
# Loss: 870930.7799518551
# Training step:  1824
# Loss: 667469.1288896936
# Training step:  1825
# Loss: 870918.264614644
# Training step:  1826
# Loss: 667456.3631529588
# Training step:  1827
# Loss: 870905.7717172159
# Training step:  1828
# Loss: 667443.6202242225
# Training step:  1829
# Loss: 870893.3011991314
# Training step:  1830
# Loss: 667430.9000416984
# Training step:  1831
# Loss: 870880.8530000425
# Training step:  1832
# Loss: 667418.2025439788
# Training step:  1833
# Loss: 870868.4270599788
# Training step:  1834
# Loss: 667405.5276697263
# Training step:  1835
# Loss: 870856.0233189807
# Training step:  1836
# Loss: 667392.8753580672
# Training step:  1837
# Loss: 870843.6417178244
# Training step:  1838
# Loss: 667380.2455483468
# Training step:  1839
# Loss: 870831.2821971636
# Training step:  1840
# Loss: 667367.638179979
# Training step:  1841
# Loss: 870818.9446977043
# Training step:  1842
# Loss: 667355.0531925275
# Training step:  1843
# Loss: 870806.629160531
# Training step:  1844
# Loss: 667342.4905261064
# Training step:  1845
# Loss: 870794.3355272841
# Training step:  1846
# Loss: 667329.9501208861
# Training step:  1847
# Loss: 870782.06373937
# Training step:  1848
# Loss: 667317.4319172087
# Training step:  1849
# Loss: 870769.8137385703
# Training step:  1850
# Loss: 667304.9358556498
# Training step:  1851
# Loss: 870757.5854668324
# Training step:  1852
# Loss: 667292.4618770935
# Training step:  1853
# Loss: 870745.3788664916
# Training step:  1854
# Loss: 667280.0099226246
# Training step:  1855
# Loss: 870733.1938799472
# Training step:  1856
# Loss: 667267.5799334816
# Training step:  1857
# Loss: 870721.0304498578
# Training step:  1858
# Loss: 667255.1718512527
# Training step:  1859
# Loss: 870708.8885191855
# Training step:  1860
# Loss: 667242.7856176244
# Training step:  1861
# Loss: 870696.7680309477
# Training step:  1862
# Loss: 667230.421174544
# Training step:  1863
# Loss: 870684.6689284366
# Training step:  1864
# Loss: 667218.0784640937
# Training step:  1865
# Loss: 870672.591155039
# Training step:  1866
# Loss: 667205.757428719
# Training step:  1867
# Loss: 870660.5346546939
# Training step:  1868
# Loss: 667193.4580110434
# Training step:  1869
# Loss: 870648.4993712709
# Training step:  1870
# Loss: 667181.1801538935
# Training step:  1871
# Loss: 870636.4852489794
# Training step:  1872
# Loss: 667168.9238002861
# Training step:  1873
# Loss: 870624.4922321714
# Training step:  1874
# Loss: 667156.6888934723
# Training step:  1875
# Loss: 870612.520265326
# Training step:  1876
# Loss: 667144.4753767485
# Training step:  1877
# Loss: 870600.5692930379
# Training step:  1878
# Loss: 667132.2831938169
# Training step:  1879
# Loss: 870588.6392603868
# Training step:  1880
# Loss: 667120.1122884947
# Training step:  1881
# Loss: 870576.7301124557
# Training step:  1882
# Loss: 667107.9626049501
# Training step:  1883
# Loss: 870564.8417948382
# Training step:  1884
# Loss: 667095.834087434
# Training step:  1885
# Loss: 870552.9742529107
# Training step:  1886
# Loss: 667083.7266803973
# Training step:  1887
# Loss: 870541.1274325529
# Training step:  1888
# Loss: 667071.6403286237
# Training step:  1889
# Loss: 870529.3012797991
# Training step:  1890
# Loss: 667059.574976931
# Training step:  1891
# Loss: 870517.4957407012
# Training step:  1892
# Loss: 667047.5305704563
# Training step:  1893
# Loss: 870505.7107617578
# Training step:  1894
# Loss: 667035.5070545281
# Training step:  1895
# Loss: 870493.9462895173
# Training step:  1896
# Loss: 667023.5043745915
# Training step:  1897
# Loss: 870482.2022706608
# Training step:  1898
# Loss: 667011.5224763595
# Training step:  1899
# Loss: 870470.4786521931
# Training step:  1900
# Loss: 666999.561305693
# Training step:  1901
# Loss: 870458.7753811587
# Training step:  1902
# Loss: 666987.6208086535
# Training step:  1903
# Loss: 870447.0924048986
# Training step:  1904
# Loss: 666975.7009315443
# Training step:  1905
# Loss: 870435.4296709774
# Training step:  1906
# Loss: 666963.801620862
# Training step:  1907
# Loss: 870423.78712712
# Training step:  1908
# Loss: 666951.9228233562
# Training step:  1909
# Loss: 870412.1647214431
# Training step:  1910
# Loss: 666940.0644859617
# Training step:  1911
# Loss: 870400.5624019105
# Training step:  1912
# Loss: 666928.2265555911
# Training step:  1913
# Loss: 870388.9801167182
# Training step:  1914
# Loss: 666916.4089796253
# Training step:  1915
# Loss: 870377.4178145959
# Training step:  1916
# Loss: 666904.6117055364
# Training step:  1917
# Loss: 870365.8754440111
# Training step:  1918
# Loss: 666892.8346808315
# Training step:  1919
# Loss: 870354.3529538221
# Training step:  1920
# Loss: 666881.0778535157
# Training step:  1921
# Loss: 870342.8502932817
# Training step:  1922
# Loss: 666869.3411715946
# Training step:  1923
# Loss: 870331.3674114592
# Training step:  1924
# Loss: 666857.6245831784
# Training step:  1925
# Loss: 870319.9042576781
# Training step:  1926
# Loss: 666845.9280366701
# Training step:  1927
# Loss: 870308.46078155
# Training step:  1928
# Loss: 666834.251480695
# Training step:  1929
# Loss: 870297.036932876
# Training step:  1930
# Loss: 666822.5948639713
# Training step:  1931
# Loss: 870285.6326615257
# Training step:  1932
# Loss: 666810.9581355081
# Training step:  1933
# Loss: 870274.2479178295
# Training step:  1934
# Loss: 666799.3412445614
# Training step:  1935
# Loss: 870262.8826521311
# Training step:  1936
# Loss: 666787.7441403677
# Training step:  1937
# Loss: 870251.5368147668
# Training step:  1938
# Loss: 666776.1667724021
# Training step:  1939
# Loss: 870240.2103563822
# Training step:  1940
# Loss: 666764.6090903507
# Training step:  1941
# Loss: 870228.9032279002
# Training step:  1942
# Loss: 666753.071044154
# Training step:  1943
# Loss: 870217.6153803805
# Training step:  1944
# Loss: 666741.5525838545
# Training step:  1945
# Loss: 870206.3467650479
# Training step:  1946
# Loss: 666730.0536597107
# Training step:  1947
# Loss: 870195.0973332082
# Training step:  1948
# Loss: 666718.5742219965
# Training step:  1949
# Loss: 870183.8670362174
# Training step:  1950
# Loss: 666707.1142212619
# Training step:  1951
# Loss: 870172.6558258532
# Training step:  1952
# Loss: 666695.6736083494
# Training step:  1953
# Loss: 870161.4636541232
# Training step:  1954
# Loss: 666684.2523342478
# Training step:  1955
# Loss: 870150.2904731166
# Training step:  1956
# Loss: 666672.8503500365
# Training step:  1957
# Loss: 870139.1362350119
# Training step:  1958
# Loss: 666661.4676070189
# Training step:  1959
# Loss: 870128.0008922523
# Training step:  1960
# Loss: 666650.1040566411
# Training step:  1961
# Loss: 870116.8843973383
# Training step:  1962
# Loss: 666638.7596504502
# Training step:  1963
# Loss: 870105.7867028964
# Training step:  1964
# Loss: 666627.4343402738
# Training step:  1965
# Loss: 870094.7077619646
# Training step:  1966
# Loss: 666616.1280781502
# Training step:  1967
# Loss: 870083.6475276032
# Training step:  1968
# Loss: 666604.8408161865
# Training step:  1969
# Loss: 870072.6059530727
# Training step:  1970
# Loss: 666593.572506732
# Training step:  1971
# Loss: 870061.5829917614
# Training step:  1972
# Loss: 666582.3231021769
# Training step:  1973
# Loss: 870050.5785970526
# Training step:  1974
# Loss: 666571.0925551904
# Training step:  1975
# Loss: 870039.59272291
# Training step:  1976
# Loss: 666559.880818668
# Training step:  1977
# Loss: 870028.6253231337
# Training step:  1978
# Loss: 666548.6878454798
# Training step:  1979
# Loss: 870017.6763516332
# Training step:  1980
# Loss: 666537.5135887214
# Training step:  1981
# Loss: 870006.745762661
# Training step:  1982
# Loss: 666526.3580017928
# Training step:  1983
# Loss: 869995.8335106445
# Training step:  1984
# Loss: 666515.2210380883
# Training step:  1985
# Loss: 869984.9395500399
# Training step:  1986
# Loss: 666504.1026513778
# Training step:  1987
# Loss: 869974.0638357796
# Training step:  1988
# Loss: 666493.0027954315
# Training step:  1989
# Loss: 869963.2063225801
# Training step:  1990
# Loss: 666481.9214242423
# Training step:  1991
# Loss: 869952.3669655197
# Training step:  1992
# Loss: 666470.8584918511
# Training step:  1993
# Loss: 869941.5457195978
# Training step:  1994
# Loss: 666459.8139525368
# Training step:  1995
# Loss: 869930.7425401792
# Training step:  1996
# Loss: 666448.7877606794
# Training step:  1997
# Loss: 869919.9573825623
# Training step:  1998
# Loss: 666437.779870825
# Training step:  1999
# Loss: 869909.1902024563
# Loss_min: tensor(283867.6553, grad_fn=<AddBackward0>)

# %%
load_model_predict(model_city_date_path, data_hubei, city_name='湖北')
# Out:
# [  270   375   444   549   729  1052  1423  2714  3554  4586  5806  7153
#   9074 11177 13522 16678 19665 22112 24953 27100 29631]

# %%
def read_china_data(path):
    data = pd.read_csv(path)
    data['I'] = data['confirmed']-data['dead']-data['cured']
    data['E']=data['suspected']+data['close_contact']+data['under_medical_observation']
    data['time']= pd.to_datetime(data['time'])
    # data['time'] = data['time'].apply(lambda x:x-np.timedelta64(1,'D'))
    return data

# %%
data_china = read_china_data('./ncov/data/nation_截至0209_24时.csv')
data_china

# %%
N_init = (max(data_china['E'])+max(data_china['I'])+max(data_china['cured'])+max(data_china['dead']))*100.
model_city_date_path = train_with_city_data(data_china,N_init,'02-10','全国',max_epoches=6000)
# Out:
# 505
# Training step:  1564
# Loss: 1651905.0796228957
# Training step:  1565
# Loss: 1270785.2603281913
# Training step:  1566
# Loss: 1651863.4592052896
# Training step:  1567
# Loss: 1270743.7335363738
# Training step:  1568
# Loss: 1651821.9438343046
# Training step:  1569
# Loss: 1270702.3114407167
# Training step:  1570
# Loss: 1651780.533124434
# Training step:  1571
# Loss: 1270660.9936566819
# Training step:  1572
# Loss: 1651739.2266921962
# Training step:  1573
# Loss: 1270619.779801752
# Training step:  1574
# Loss: 1651698.0241563572
# Training step:  1575
# Loss: 1270578.669495607
# Training step:  1576
# Loss: 1651656.9251378407
# Training step:  1577
# Loss: 1270537.6623597245
# Training step:  1578
# Loss: 1651615.9292589747
# Training step:  1579
# Loss: 1270496.7580171686
# Training step:  1580
# Loss: 1651575.0361438144
# Training step:  1581
# Loss: 1270455.9560927916
# Training step:  1582
# Loss: 1651534.245418209
# Training step:  1583
# Loss: 1270415.2562136666
# Training step:  1584
# Loss: 1651493.5567105804
# Training step:  1585
# Loss: 1270374.65800857
# Training step:  1586
# Loss: 1651452.9696503181
# Training step:  1587
# Loss: 1270334.1611078589
# Training step:  1588
# Loss: 1651412.4838690208
# Training step:  1589
# Loss: 1270293.7651440152
# Training step:  1590
# Loss: 1651372.0990000693
# Training step:  1591
# Loss: 1270253.469751186
# Training step:  1592
# Loss: 1651331.8146787577
# Training step:  1593
# Loss: 1270213.2745655456
# Training step:  1594
# Loss: 1651291.6305422934
# Training step:  1595
# Loss: 1270173.1792247926
# Training step:  1596
# Loss: 1651251.546229151
# Training step:  1597
# Loss: 1270133.1833683548
# Training step:  1598
# Loss: 1651211.5613798103
# Training step:  1599
# Loss: 1270093.286637577
# Training step:  1600
# Loss: 1651171.6756366696
# Training step:  1601
# Loss: 1270053.4886755198
# Training step:  1602
# Loss: 1651131.8886435414
# Training step:  1603
# Loss: 1270013.7891267496
# Training step:  1604
# Loss: 1651092.2000459416
# Training step:  1605
# Loss: 1269974.1876378455
# Training step:  1606
# Loss: 1651052.6094915697
# Training step:  1607
# Loss: 1269934.6838571152
# Training step:  1608
# Loss: 1651013.1166296427
# Training step:  1609
# Loss: 1269895.2774345023
# Training step:  1610
# Loss: 1650973.7211108648
# Training step:  1611
# Loss: 1269855.9680214587
# Training step:  1612
# Loss: 1650934.4225876564
# Training step:  1613
# Loss: 1269816.7552713198
# Training step:  1614
# Loss: 1650895.220714269
# Training step:  1615
# Loss: 1269777.6388389617
# Training step:  1616
# Loss: 1650856.1151461818
# Training step:  1617
# Loss: 1269738.6183808583
# Training step:  1618
# Loss: 1650817.105541085
# Training step:  1619
# Loss: 1269699.6935554715
# Training step:  1620
# Loss: 1650778.1915582225
# Training step:  1621
# Loss: 1269660.8640226903
# Training step:  1622
# Loss: 1650739.3728582787
# Training step:  1623
# Loss: 1269622.1294440783
# Training step:  1624
# Loss: 1650700.6491037444
# Training step:  1625
# Loss: 1269583.4894827781
# Training step:  1626
# Loss: 1650662.0199586472
# Training step:  1627
# Loss: 1269544.9438036848
# Training step:  1628
# Loss: 1650623.4850886136
# Training step:  1629
# Loss: 1269506.4920730647
# Training step:  1630
# Loss: 1650585.0441607619
# Training step:  1631
# Loss: 1269468.1339589048
# Training step:  1632
# Loss: 1650546.6968439112
# Training step:  1633
# Loss: 1269429.8691307646
# Training step:  1634
# Loss: 1650508.442808368
# Training step:  1635
# Loss: 1269391.6972597467
# Training step:  1636
# Loss: 1650470.2817261172
# Training step:  1637
# Loss: 1269353.6180186153
# Training step:  1638
# Loss: 1650432.2132707522
# Training step:  1639
# Loss: 1269315.6310816812
# Training step:  1640
# Loss: 1650394.2371172328
# Training step:  1641
# Loss: 1269277.736124493
# Training step:  1642
# Loss: 1650356.3529417983
# Training step:  1643
# Loss: 1269239.9328244785
# Training step:  1644
# Loss: 1650318.560422931
# Training step:  1645
# Loss: 1269202.2208606799
# Training step:  1646
# Loss: 1650280.859240442
# Training step:  1647
# Loss: 1269164.599913522
# Training step:  1648
# Loss: 1650243.2490753047
# Training step:  1649
# Loss: 1269127.069664662
# Training step:  1650
# Loss: 1650205.7296098792
# Training step:  1651
# Loss: 1269089.6297975166
# Training step:  1652
# Loss: 1650168.3005284446
# Training step:  1653
# Loss: 1269052.2799969853
# Training step:  1654
# Loss: 1650130.9615166227
# Training step:  1655
# Loss: 1269015.019949504
# Training step:  1656
# Loss: 1650093.712261711
# Training step:  1657
# Loss: 1268977.8493430386
# Training step:  1658
# Loss: 1650056.552452217
# Training step:  1659
# Loss: 1268940.7678667295
# Training step:  1660
# Loss: 1650019.48177801
# Training step:  1661
# Loss: 1268903.7752113827
# Training step:  1662
# Loss: 1649982.499930664
# Training step:  1663
# Loss: 1268866.8710691617
# Training step:  1664
# Loss: 1649945.606602863
# Training step:  1665
# Loss: 1268830.0551335923
# Training step:  1666
# Loss: 1649908.801488918
# Training step:  1667
# Loss: 1268793.3270998653
# Training step:  1668
# Loss: 1649872.084284773
# Training step:  1669
# Loss: 1268756.6866644535
# Training step:  1670
# Loss: 1649835.4546874731
# Training step:  1671
# Loss: 1268720.1335253322
# Training step:  1672
# Loss: 1649798.9123957918
# Training step:  1673
# Loss: 1268683.667381812
# Training step:  1674
# Loss: 1649762.457109627
# Training step:  1675
# Loss: 1268647.2879346656
# Training step:  1676
# Loss: 1649726.0885304313
# Training step:  1677
# Loss: 1268610.9948858803
# Training step:  1678
# Loss: 1649689.8063607337
# Training step:  1679
# Loss: 1268574.7879389958
# Training step:  1680
# Loss: 1649653.610304965
# Training step:  1681
# Loss: 1268538.666799032
# Training step:  1682
# Loss: 1649617.5000686008
# Training step:  1683
# Loss: 1268502.6311720142
# Training step:  1684
# Loss: 1649581.4753582147
# Training step:  1685
# Loss: 1268466.6807655029
# Training step:  1686
# Loss: 1649545.5358821522
# Training step:  1687
# Loss: 1268430.8152885803
# Training step:  1688
# Loss: 1649509.6813501448
# Training step:  1689
# Loss: 1268395.0344515105
# Training step:  1690
# Loss: 1649473.9114729152
# Training step:  1691
# Loss: 1268359.337965757
# Training step:  1692
# Loss: 1649438.2259625415
# Training step:  1693
# Loss: 1268323.7255442461
# Training step:  1694
# Loss: 1649402.6245325557
# Training step:  1695
# Loss: 1268288.196901245
# Training step:  1696
# Loss: 1649367.1068978768
# Training step:  1697
# Loss: 1268252.7517523179
# Training step:  1698
# Loss: 1649331.67277466
# Training step:  1699
# Loss: 1268217.3898144993
# Training step:  1700
# Loss: 1649296.3218806018
# Training step:  1701
# Loss: 1268182.1108057762
# Training step:  1702
# Loss: 1649261.053934002
# Training step:  1703
# Loss: 1268146.9144455027
# Training step:  1704
# Loss: 1649225.8686548981
# Training step:  1705
# Loss: 1268111.8004544878
# Training step:  1706
# Loss: 1649190.7657647778
# Training step:  1707
# Loss: 1268076.7685547417
# Training step:  1708
# Loss: 1649155.7449860815
# Training step:  1709
# Loss: 1268041.8184695225
# Training step:  1710
# Loss: 1649120.806042698
# Training step:  1711
# Loss: 1268006.9499233535
# Training step:  1712
# Loss: 1649085.9486596393
# Training step:  1713
# Loss: 1267972.162641943
# Training step:  1714
# Loss: 1649051.172563127
# Training step:  1715
# Loss: 1267937.4563523405
# Training step:  1716
# Loss: 1649016.4774808872
# Training step:  1717
# Loss: 1267902.830782807
# Training step:  1718
# Loss: 1648981.863141472
# Training step:  1719
# Loss: 1267868.2856627125
# Training step:  1720
# Loss: 1648947.3292749445
# Training step:  1721
# Loss: 1267833.820722782
# Training step:  1722
# Loss: 1648912.8756124435
# Training step:  1723
# Loss: 1267799.435695014
# Training step:  1724
# Loss: 1648878.501886815
# Training step:  1725
# Loss: 1267765.130312756
# Training step:  1726
# Loss: 1648844.2078316137
# Training step:  1727
# Loss: 1267730.9043099633
# Training step:  1728
# Loss: 1648809.9931811413
# Training step:  1729
# Loss: 1267696.757422274
# Training step:  1730
# Loss: 1648775.8576719537
# Training step:  1731
# Loss: 1267662.6893864032
# Training step:  1732
# Loss: 1648741.801040883
# Training step:  1733
# Loss: 1267628.6999401862
# Training step:  1734
# Loss: 1648707.8230264324
# Training step:  1735
# Loss: 1267594.788822678
# Training step:  1736
# Loss: 1648673.9233680519
# Training step:  1737
# Loss: 1267560.955774107
# Training step:  1738
# Loss: 1648640.1018065307
# Training step:  1739
# Loss: 1267527.2005358806
# Training step:  1740
# Loss: 1648606.358083706
# Training step:  1741
# Loss: 1267493.522850506
# Training step:  1742
# Loss: 1648572.6919424878
# Training step:  1743
# Loss: 1267459.92246166
# Training step:  1744
# Loss: 1648539.1031270388
# Training step:  1745
# Loss: 1267426.3991141024
# Training step:  1746
# Loss: 1648505.5913825817
# Training step:  1747
# Loss: 1267392.9525538809
# Training step:  1748
# Loss: 1648472.1564557035
# Training step:  1749
# Loss: 1267359.5825281236
# Training step:  1750
# Loss: 1648438.79809389
# Training step:  1751
# Loss: 1267326.288785071
# Training step:  1752
# Loss: 1648405.5160459757
# Training step:  1753
# Loss: 1267293.0710740702
# Training step:  1754
# Loss: 1648372.3100615286
# Training step:  1755
# Loss: 1267259.9291454782
# Training step:  1756
# Loss: 1648339.1798914708
# Training step:  1757
# Loss: 1267226.8627508383
# Training step:  1758
# Loss: 1648306.1252877133
# Training step:  1759
# Loss: 1267193.8716428906
# Training step:  1760
# Loss: 1648273.1460035024
# Training step:  1761
# Loss: 1267160.9555752527
# Training step:  1762
# Loss: 1648240.2417927713
# Training step:  1763
# Loss: 1267128.1143027938
# Training step:  1764
# Loss: 1648207.4124108031
# Training step:  1765
# Loss: 1267095.3475813146
# Training step:  1766
# Loss: 1648174.6576138444
# Training step:  1767
# Loss: 1267062.6551678153
# Training step:  1768
# Loss: 1648141.9771593018
# Training step:  1769
# Loss: 1267030.0368204252
# Training step:  1770
# Loss: 1648109.3708057876
# Training step:  1771
# Loss: 1266997.4922981996
# Training step:  1772
# Loss: 1648076.8383126063
# Training step:  1773
# Loss: 1266965.0213612553
# Training step:  1774
# Loss: 1648044.37944036
# Training step:  1775
# Loss: 1266932.6237708158
# Training step:  1776
# Loss: 1648011.993950631
# Training step:  1777
# Loss: 1266900.2992891183
# Training step:  1778
# Loss: 1647979.6816060743
# Training step:  1779
# Loss: 1266868.0476794748
# Training step:  1780
# Loss: 1647947.4421703483
# Training step:  1781
# Loss: 1266835.8687061358
# Training step:  1782
# Loss: 1647915.2754080393
# Training step:  1783
# Loss: 1266803.7621344796
# Training step:  1784
# Loss: 1647883.1810850298
# Training step:  1785
# Loss: 1266771.727730854
# Training step:  1786
# Loss: 1647851.1589678212
# Training step:  1787
# Loss: 1266739.7652625823
# Training step:  1788
# Loss: 1647819.208824324
# Training step:  1789
# Loss: 1266707.8744980958
# Training step:  1790
# Loss: 1647787.3304230915
# Training step:  1791
# Loss: 1266676.055206636
# Training step:  1792
# Loss: 1647755.523533815
# Training step:  1793
# Loss: 1266644.3071586776
# Training step:  1794
# Loss: 1647723.7879274618
# Training step:  1795
# Loss: 1266612.6301257573
# Training step:  1796
# Loss: 1647692.1233758964
# Training step:  1797
# Loss: 1266581.0238801378
# Training step:  1798
# Loss: 1647660.5296514789
# Training step:  1799
# Loss: 1266549.488194989
# Training step:  1800
# Loss: 1647629.0065278723
# Training step:  1801
# Loss: 1266518.0228448294
# Training step:  1802
# Loss: 1647597.5537800814
# Training step:  1803
# Loss: 1266486.6276049837
# Training step:  1804
# Loss: 1647566.1711835484
# Training step:  1805
# Loss: 1266455.3022515697
# Training step:  1806
# Loss: 1647534.858514801
# Training step:  1807
# Loss: 1266424.046561907
# Training step:  1808
# Loss: 1647503.6155514896
# Training step:  1809
# Loss: 1266392.8603140984
# Training step:  1810
# Loss: 1647472.4420719782
# Training step:  1811
# Loss: 1266361.743287238
# Training step:  1812
# Loss: 1647441.337855664
# Training step:  1813
# Loss: 1266330.6952614002
# Training step:  1814
# Loss: 1647410.3026830868
# Training step:  1815
# Loss: 1266299.7160177608
# Training step:  1816
# Loss: 1647379.3363356872
# Training step:  1817
# Loss: 1266268.8053381278
# Training step:  1818
# Loss: 1647348.438595407
# Training step:  1819
# Loss: 1266237.9630052876
# Training step:  1820
# Loss: 1647317.6092454821
# Training step:  1821
# Loss: 1266207.1888032102
# Training step:  1822
# Loss: 1647286.8480702455
# Training step:  1823
# Loss: 1266176.482516536
# Training step:  1824
# Loss: 1647256.1548545018
# Training step:  1825
# Loss: 1266145.843930906
# Training step:  1826
# Loss: 1647225.5293841483
# Training step:  1827
# Loss: 1266115.272832683
# Training step:  1828
# Loss: 1647194.9714458778
# Training step:  1829
# Loss: 1266084.7690095177
# Training step:  1830
# Loss: 1647164.4808278484
# Training step:  1831
# Loss: 1266054.332249851
# Training step:  1832
# Loss: 1647134.057318657
# Training step:  1833
# Loss: 1266023.962342927
# Training step:  1834
# Loss: 1647103.7007077816
# Training step:  1835
# Loss: 1265993.6590787135
# Training step:  1836
# Loss: 1647073.4107852993
# Training step:  1837
# Loss: 1265963.4222480895
# Training step:  1838
# Loss: 1647043.1873424607
# Training step:  1839
# Loss: 1265933.2516430113
# Training step:  1840
# Loss: 1647013.0301716279
# Training step:  1841
# Loss: 1265903.1470564622
# Training step:  1842
# Loss: 1646982.9390661495
# Training step:  1843
# Loss: 1265873.108282157
# Training step:  1844
# Loss: 1646952.9138197813
# Training step:  1845
# Loss: 1265843.135114332
# Training step:  1846
# Loss: 1646922.9542269274
# Training step:  1847
# Loss: 1265813.2273484014
# Training step:  1848
# Loss: 1646893.0600834796
# Training step:  1849
# Loss: 1265783.3847806908
# Training step:  1850
# Loss: 1646863.2311859918
# Training step:  1851
# Loss: 1265753.6072083004
# Training step:  1852
# Loss: 1646833.4673318118
# Training step:  1853
# Loss: 1265723.8944291174
# Training step:  1854
# Loss: 1646803.7683188636
# Training step:  1855
# Loss: 1265694.2462417786
# Training step:  1856
# Loss: 1646774.1339462434
# Training step:  1857
# Loss: 1265664.6624460474
# Training step:  1858
# Loss: 1646744.5640139428
# Training step:  1859
# Loss: 1265635.1428424246
# Training step:  1860
# Loss: 1646715.0583227258
# Training step:  1861
# Loss: 1265605.687232083
# Training step:  1862
# Loss: 1646685.6166737608
# Training step:  1863
# Loss: 1265576.2954170578
# Training step:  1864
# Loss: 1646656.2388696242
# Training step:  1865
# Loss: 1265546.9672005302
# Training step:  1866
# Loss: 1646626.924713719
# Training step:  1867
# Loss: 1265517.7023861504
# Training step:  1868
# Loss: 1646597.6740097238
# Training step:  1869
# Loss: 1265488.5007784516
# Training step:  1870
# Loss: 1646568.4865624683
# Training step:  1871
# Loss: 1265459.362182716
# Training step:  1872
# Loss: 1646539.3621774737
# Training step:  1873
# Loss: 1265430.2864051997
# Training step:  1874
# Loss: 1646510.3006612293
# Training step:  1875
# Loss: 1265401.2732528334
# Training step:  1876
# Loss: 1646481.3018207953
# Training step:  1877
# Loss: 1265372.3225332773
# Training step:  1878
# Loss: 1646452.3654640403
# Training step:  1879
# Loss: 1265343.4340552837
# Training step:  1880
# Loss: 1646423.4914002642
# Training step:  1881
# Loss: 1265314.6076283497
# Training step:  1882
# Loss: 1646394.6794389314
# Training step:  1883
# Loss: 1265285.8430623775
# Training step:  1884
# Loss: 1646365.929389916
# Training step:  1885
# Loss: 1265257.1401681714
# Training step:  1886
# Loss: 1646337.2410644807
# Training step:  1887
# Loss: 1265228.4987575277
# Training step:  1888
# Loss: 1646308.614274612
# Training step:  1889
# Loss: 1265199.9186430096
# Training step:  1890
# Loss: 1646280.0488332044
# Training step:  1891
# Loss: 1265171.3996378963
# Training step:  1892
# Loss: 1646251.544553517
# Training step:  1893
# Loss: 1265142.9415559852
# Training step:  1894
# Loss: 1646223.1012494278
# Training step:  1895
# Loss: 1265114.544211916
# Training step:  1896
# Loss: 1646194.7187359084
# Training step:  1897
# Loss: 1265086.20742129
# Training step:  1898
# Loss: 1646166.3968288302
# Training step:  1899
# Loss: 1265057.9310005016
# Training step:  1900
# Loss: 1646138.1353448583
# Training step:  1901
# Loss: 1265029.7147666963
# Training step:  1902
# Loss: 1646109.9341012624
# Training step:  1903
# Loss: 1265001.5585374816
# Training step:  1904
# Loss: 1646081.7929156327
# Training step:  1905
# Loss: 1264973.462131236
# Training step:  1906
# Loss: 1646053.7116067188
# Training step:  1907
# Loss: 1264945.4253673526
# Training step:  1908
# Loss: 1646025.6899940686
# Training step:  1909
# Loss: 1264917.4480656653
# Training step:  1910
# Loss: 1645997.7278975672
# Training step:  1911
# Loss: 1264889.530046826
# Training step:  1912
# Loss: 1645969.825138086
# Training step:  1913
# Loss: 1264861.6711322388
# Training step:  1914
# Loss: 1645941.9815371484
# Training step:  1915
# Loss: 1264833.871144015
# Training step:  1916
# Loss: 1645914.1969172035
# Training step:  1917
# Loss: 1264806.1299051216
# Training step:  1918
# Loss: 1645886.4711012156
# Training step:  1919
# Loss: 1264778.447239122
# Training step:  1920
# Loss: 1645858.8039132005
# Training step:  1921
# Loss: 1264750.8229704266
# Training step:  1922
# Loss: 1645831.1951774412
# Training step:  1923
# Loss: 1264723.2569237957
# Training step:  1924
# Loss: 1645803.6447188621
# Training step:  1925
# Loss: 1264695.7489249702
# Training step:  1926
# Loss: 1645776.152363552
# Training step:  1927
# Loss: 1264668.2988004175
# Training step:  1928
# Loss: 1645748.7179380148
# Training step:  1929
# Loss: 1264640.9063771826
# Training step:  1930
# Loss: 1645721.3412693515
# Training step:  1931
# Loss: 1264613.5714828558
# Training step:  1932
# Loss: 1645694.0221853498
# Training step:  1933
# Loss: 1264586.2939460294
# Training step:  1934
# Loss: 1645666.7605148922
# Training step:  1935
# Loss: 1264559.0735958864
# Training step:  1936
# Loss: 1645639.55608714
# Training step:  1937
# Loss: 1264531.910262217
# Training step:  1938
# Loss: 1645612.4087321784
# Training step:  1939
# Loss: 1264504.803775623
# Training step:  1940
# Loss: 1645585.318280698
# Training step:  1941
# Loss: 1264477.7539672144
# Training step:  1942
# Loss: 1645558.2845638494
# Training step:  1943
# Loss: 1264450.7606688088
# Training step:  1944
# Loss: 1645531.307413695
# Training step:  1945
# Loss: 1264423.8237129783
# Training step:  1946
# Loss: 1645504.3866629351
# Training step:  1947
# Loss: 1264396.9429329215
# Training step:  1948
# Loss: 1645477.5221448776
# Training step:  1949
# Loss: 1264370.1181624935
# Training step:  1950
# Loss: 1645450.7136935783
# Training step:  1951
# Loss: 1264343.3492362455
# Training step:  1952
# Loss: 1645423.961143632
# Training step:  1953
# Loss: 1264316.635989195
# Training step:  1954
# Loss: 1645397.2643300865
# Training step:  1955
# Loss: 1264289.978257126
# Training step:  1956
# Loss: 1645370.623088931
# Training step:  1957
# Loss: 1264263.3758765624
# Training step:  1958
# Loss: 1645344.0372570036
# Training step:  1959
# Loss: 1264236.8286847766
# Training step:  1960
# Loss: 1645317.506671602
# Training step:  1961
# Loss: 1264210.336519511
# Training step:  1962
# Loss: 1645291.0311705354
# Training step:  1963
# Loss: 1264183.8992190023
# Training step:  1964
# Loss: 1645264.6105921026
# Training step:  1965
# Loss: 1264157.5166222753
# Training step:  1966
# Loss: 1645238.2447754608
# Training step:  1967
# Loss: 1264131.1885689052
# Training step:  1968
# Loss: 1645211.9335603213
# Training step:  1969
# Loss: 1264104.9148993022
# Training step:  1970
# Loss: 1645185.6767873405
# Training step:  1971
# Loss: 1264078.695454416
# Training step:  1972
# Loss: 1645159.474297365
# Training step:  1973
# Loss: 1264052.5300755948
# Training step:  1974
# Loss: 1645133.325931958
# Training step:  1975
# Loss: 1264026.4186051409
# Training step:  1976
# Loss: 1645107.231533552
# Training step:  1977
# Loss: 1264000.3608857924
# Training step:  1978
# Loss: 1645081.1909449406
# Training step:  1979
# Loss: 1263974.3567608683
# Training step:  1980
# Loss: 1645055.204009611
# Training step:  1981
# Loss: 1263948.406074494
# Training step:  1982
# Loss: 1645029.2705717569
# Training step:  1983
# Loss: 1263922.5086711831
# Training step:  1984
# Loss: 1645003.390476012
# Training step:  1985
# Loss: 1263896.6643961512
# Training step:  1986
# Loss: 1644977.563567634
# Training step:  1987
# Loss: 1263870.8730952074
# Training step:  1988
# Loss: 1644951.7896925486
# Training step:  1989
# Loss: 1263845.1346146644
# Training step:  1990
# Loss: 1644926.0686971832
# Training step:  1991
# Loss: 1263819.4488017194
# Training step:  1992
# Loss: 1644900.400428983
# Training step:  1993
# Loss: 1263793.8155038333
# Training step:  1994
# Loss: 1644874.7847350722
# Training step:  1995
# Loss: 1263768.2345690045
# Training step:  1996
# Loss: 1644849.2214638907
# Training step:  1997
# Loss: 1263742.7058462566
# Training step:  1998
# Loss: 1644823.710464571
# Training step:  1999
# Loss: 1263717.2291849446
# Loss_min: tensor(82384.2391, grad_fn=<AddBackward0>)

# %%
load_model_predict(model_city_date_path, data_china, city_name='全国')
# Out:
# [  291   440   571   830  1287  1975  2744  4515  5974  7711  9692 11791
#  14380 17205 20438 24324 28018 31161 34546 37198 40171]

# %%
model_city_date_paths = ['models/shenzhen/02-08','models/wuhan/02-08','models/hubei/02-08','models/china/02-08']

# %%
for model_i in range(len(model_city_date_paths)):
    print(model_city_date_paths[model_i]+':{')
    model_city_date_path = model_city_date_paths[model_i]
    model_pt = os.path.join(model_city_date_path,'model.pt')
    model = torch.load(model_pt)
    beta = []
    for i in range(len(model.SEIR_cells)):
        beta.append(model.SEIR_cells[i].beta.detach().numpy()[0])
    print(f'beta_model_{model_i}:{beta}')
    gamma_2 = []
    for i in range(len(model.SEIR_cells)):
        gamma_2.append(model.SEIR_cells[i].gamma_2.detach().numpy()[0])
    print(f'gamma_2_model_{model_i}:{gamma_2}')
    N = []
    for i in range(len(model.SEIR_cells)):
        N.append(model.SEIR_cells[i].N.detach().numpy()[0])
    print(f'N_model_{model_i}:{N}')    
    theta = []
    for i in range(len(model.SEIR_cells)):
        theta.append(model.SEIR_cells[i].theta.detach().numpy()[0])
    print(f'theta_model_{model_i}:{theta}')  
    print('}')

# %%
len(model.SEIR_cells)

# %%
beta_sz = []
for i in range(len(model.SEIR_cells)):
    beta_sz.append(model.SEIR_cells[i].beta.detach().numpy()[0])
beta_sz
